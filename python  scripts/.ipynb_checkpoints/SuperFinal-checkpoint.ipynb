# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from sklearn.neural_network import MLPRegressor
import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
import seaborn as sns

# %%
# new_toll_time = pd.read_csv('new_toll_time_no_0.csv')

# %%
# new_toll_time.shape

# %%
# new_toll_time.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
toll = pd.read_csv('time_between_two_tolls.csv')

# %%
toll.head(5)
# Out:
#        origin destination                                 toll_both  \
# 0  Jamshedpur       HOSUR  Main Toll (Gosthani Gate) (Sheela Nagar)
# 1  Jamshedpur       HOSUR  Main Toll (Gosthani Gate) (Sheela Nagar)
# 2  Jamshedpur       HOSUR  Main Toll (Gosthani Gate) (Sheela Nagar)
# 3  Jamshedpur       HOSUR  Main Toll (Gosthani Gate) (Sheela Nagar)
# 4  Jamshedpur       HOSUR  Main Toll (Gosthani Gate) (Sheela Nagar)
#
#    vehicle_no     loading_out_time  odometer_km        ist_timestamp  \
# 0  JH01AE6027  2017-11-06 00:16:58      7907.41  2017-11-10 22:00:15
# 1   TN36Y9906  2017-11-04 23:23:59      6801.69  2017-11-07 01:23:32
# 2   KA51A0876  2017-10-04 23:55:01      3544.38  2017-10-06 15:18:55
# 3   OR11D4683  2017-10-05 01:15:48      1642.85  2017-10-08 03:21:59
# 4   TN30U6751  2017-10-03 11:32:58      4092.77  2017-10-05 21:06:44
#
#    distance_from_toll      loading_in_time           start_date  \
# 0            0.861485  2017-11-04 20:05:00  2017-11-04 00:00:00
# 1            0.991380  2017-11-04 05:45:21  2017-11-04 00:00:00
# 2            0.926986  2017-10-04 15:22:08  2017-10-04 00:00:00
# 3            0.933659  2017-10-04 13:55:45  2017-10-04 00:00:00
# 4            0.902485  2017-10-03 06:33:28  2017-10-03 00:00:00
#
#                    eta    unloading_in_time      slug
# 0  2017-11-13 00:00:00  2017-11-13 01:39:39  ETJ0E000
# 1  2017-11-16 00:00:00  2017-11-10 03:37:24  ETOYD000
# 2  2017-10-16 00:00:00  2017-10-07 21:38:32  ETUBB000
# 3  2017-10-12 00:00:00  2017-10-10 20:27:07  ET7BB000
# 4  2017-10-14 00:00:00  2017-10-07 09:16:38  ET78B000

# %%
toll['ist_timestamp'] = toll['ist_timestamp'].apply(lambda x:datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
toll['loading_out_time'] = toll['loading_out_time'].apply(lambda x:datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S') )
toll['hours']  = toll['ist_timestamp'] - toll['loading_out_time']
toll['hours'] = toll.hours.apply(lambda x:x.total_seconds()/3600)

# %%
toll['distance_travelled'] = 0.0
toll['time_taken'] = toll['hours']
toll['time_btn_tolls'] = 0

# %%
new_time = pd.DataFrame(columns=toll.columns.tolist())

# %%
for truck in toll.vehicle_no.unique().tolist():
    for st_time in toll.start_date.unique().tolist():
        df = toll[(toll.vehicle_no == truck) & (toll.start_date == st_time)].sort_values('odometer_km')
        df.distance_travelled = df.odometer_km.diff()
        df.time_btn_tolls = df.hours.diff()
        new_time = new_time.append(df)

# %%
new_time = new_time.loc[new_time['distance_travelled'] != 0]
new_time = new_time.fillna(0)

# %%
new_time['distance_travelled_cummulative'] = 0

for truck in new_time.vehicle_no.unique().tolist():
    for st_time in new_time.start_date.unique().tolist():
        new_time.loc[(new_time['vehicle_no'] == truck) & (new_time['start_date'] == st_time), 'distance_travelled_cummulative'] = new_time.loc[(new_time['vehicle_no'] == truck) & (new_time['start_date'] == st_time)]['distance_travelled'].cumsum()

# %%
new_time.loc[new_time['time_btn_tolls'] == 0, 'time_btn_tolls']  = new_time.loc[new_time['time_btn_tolls'] == 0, 'time_taken']

# %%
new_time['delivery_status'] = 0
new_time['start_date'] = new_time['start_date'].apply(lambda x:datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S') )
new_time['eta'] = toll['eta'].apply(lambda x:datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S') )
new_time['unloading_in_time'] = new_time['unloading_in_time'].apply(lambda x:datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S') )

# %%
# toll.dtypes

# %%
new_time['delivery_status'] = (new_time['unloading_in_time'] - new_time['loading_out_time']) - (new_time['eta'] - new_time['start_date'])

# %%
new_time['delivery_status'] = new_time['delivery_status'].apply(lambda x: x.total_seconds()/3600)

# %%
new_time['delivery'] = ''

# %%
new_time.loc[new_time['delivery_status'] > 24, 'delivery'] = 'delay'
new_time.loc[(new_time['delivery_status'] <= 24) & (new_time['delivery_status'] >= 0), 'delivery'] = 'on-time'
new_time.loc[(new_time['delivery_status'] < 0), 'delivery'] = 'early'

# %%
new_time.delivery = new_time.delivery.replace({'delay':3,'on-time':2,'early':1})

# %%
today_date = datetime.datetime.now()
today_date.strftime("%Y-%m-%d %H:%M:%S")
today = today_date.strftime("%Y-%m-%d %H:%M:%S")
new_time['today'] = datetime.datetime.strptime(today, '%Y-%m-%d %H:%M:%S')

new_time['days_from_now'] = new_time['today'] - new_time['start_date'] 
new_time['days_from_now'] = new_time['days_from_now'].apply(lambda x: x.days)

new_time['avg_travel_time'] = new_time['start_date'] + (new_time['unloading_in_time'] - new_time['start_date'])/2

new_time['month_of_travel'] = new_time['avg_travel_time'].apply(lambda x: x.month)

new_time['time_of_travel'] = new_time.ist_timestamp.apply(lambda x: x.hour)

new_time['day_of_travel'] = new_time['avg_travel_time'].apply(lambda x: x.weekday())

# %%
toll_freq = dict(new_time['toll_both'].value_counts())
new_time['toll_freq'] = new_time['toll_both']
new_time['toll_freq'] = new_time['toll_freq'].apply(lambda x: toll_freq[x] )
m = int(0.3 * new_time['toll_freq'].median())
new_time = new_time[(new_time['toll_freq'] > m)]
new_time.drop(['toll_freq'], axis=1, inplace=True)

# %%
new_time.columns
# Out:
# Index([u'origin', u'destination', u'toll_both', u'vehicle_no',
#        u'loading_out_time', u'odometer_km', u'ist_timestamp',
#        u'distance_from_toll', u'loading_in_time', u'start_date', u'eta',
#        u'unloading_in_time', u'slug', u'hours', u'distance_travelled',
#        u'time_taken', u'time_btn_tolls', u'distance_travelled_cummulative',
#        u'delivery_status', u'delivery', u'today', u'days_from_now',
#        u'avg_travel_time', u'month_of_travel', u'time_of_travel',
#        u'day_of_travel'],
#       dtype='object')

# %%
new_time['median_timestamp'] = 0

# %%
for toll_b in new_time.toll_both.unique().tolist():
    new_time.loc[new_time['toll_both'] == toll_b, 'median_timestamp'] = new_time.loc[new_time['toll_both'] == toll_b]['time_taken'].median()

# %%
new_time.dtypes
# Out:
# origin                                    object
# destination                               object
# toll_both                                 object
# vehicle_no                                object
# loading_out_time                  datetime64[ns]
# odometer_km                              float64
# ist_timestamp                     datetime64[ns]
# distance_from_toll                       float64
# loading_in_time                           object
# start_date                        datetime64[ns]
# eta                               datetime64[ns]
# unloading_in_time                 datetime64[ns]
# slug                                      object
# hours                                    float64
# distance_travelled                       float64
# time_taken                               float64
# time_btn_tolls                           float64
# distance_travelled_cummulative           float64
# delivery_status                          float64
# delivery                                   int64
# today                             datetime64[ns]
# days_from_now                              int64
# avg_travel_time                   datetime64[ns]
# month_of_travel                            int64
# time_of_travel                             int64
# day_of_travel                              int64
# median_timestamp                         float64
# dtype: object

# %%
new_time['median_timestamp'] = new_time['median_timestamp'].apply(lambda x:datetime.timedelta(hours=x))
new_time['median_timestamp'] = new_time['median_timestamp'] + new_time['loading_out_time']

# %%
new_time['delay'] = new_time['ist_timestamp'] - new_time['median_timestamp']

# %%
new_time['delay'] = new_time['delay'].apply(lambda x: x.total_seconds()/3600)

# %%
new_time['loading_out_time'] = new_time['loading_out_time'].apply(lambda x: x.hour)

# %%
new_time.columns.tolist()
# Out:
# ['origin',
#  'destination',
#  'toll_both',
#  'vehicle_no',
#  'loading_out_time',
#  'odometer_km',
#  'ist_timestamp',
#  'distance_from_toll',
#  'loading_in_time',
#  'start_date',
#  'eta',
#  'unloading_in_time',
#  'slug',
#  'hours',
#  'distance_travelled',
#  'time_taken',
#  'time_btn_tolls',
#  'distance_travelled_cummulative',
#  'delivery_status',
#  'delivery',
#  'today',
#  'days_from_now',
#  'avg_travel_time',
#  'month_of_travel',
#  'time_of_travel',
#  'day_of_travel',
#  'median_timestamp',
#  'delay']

# %%
final_df = new_time[['toll_both','vehicle_no','loading_out_time','ist_timestamp','distance_travelled','distance_travelled_cummulative','time_of_travel','day_of_travel','month_of_travel','days_from_now','delivery','time_taken','delay','time_btn_tolls']]

# %%
final_df[final_df['vehicle_no'] == 'JH02M1289'].loading_out_time.value_counts()
# Out:
# 23    20
# 5     20
# 1     20
# 2     18
# Name: loading_out_time, dtype: int64

# %%
final_df[(final_df['vehicle_no'] == 'JH02M1289') & (final_df['loading_out_time'] == 23)].shape
# Out:
# (20, 14)

# %%
# new_toll_time.loc[new_toll_time['time_btn_tolls'] == 0, 'time_btn_tolls']  = new_toll_time.loc[new_toll_time['time_btn_tolls'] == 0, 'time_taken']

# %%
final_df.to_csv('SUPER_FINAL_DF.csv', index=False)

# %%
final_df['vehicle_no'][final_df['delivery'] == 3].value_counts()
# Out:
# BR02GA0735    20
# WB23C9411     19
# AP26TB0388    16
# OD04D9687     15
# WB03C9131     10
# Name: vehicle_no, dtype: int64

# %%
# JH02M1289 on-time
# TN28BB9075 early
# BR02GA0735 late

# %%
# df_late = final_df[final_df['vehicle_no'] == 'BR02GA0735']
# df_early = final_df[final_df['vehicle_no'] == 'TN28BB9075']
df_on_time = final_df[final_df['vehicle_no'] == 'JH02M1289']

# %%
test_df = pd.DataFrame(columns=df_late.columns.tolist())

# %%
test_df = test_df.append([df_late])

# %%
train_df = final_df[final_df['vehicle_no'].isin(['JH02M1289']) == False]

# %%
final_df.shape, train_df.shape, test_df.shape
# Out:
# ((3386, 14), (3308, 14), (20, 14))

# %%
final_df.columns
# Out:
# Index([u'toll_both', u'vehicle_no', u'loading_out_time', u'ist_timestamp',
#        u'distance_travelled', u'distance_travelled_cummulative',
#        u'time_of_travel', u'day_of_travel', u'month_of_travel',
#        u'days_from_now', u'delivery', u'time_taken', u'delay',
#        u'time_btn_tolls'],
#       dtype='object')

# %%
train_df_copy = train_df.copy()
test_df_copy = test_df.copy()

# %%
train_df.columns
# Out:
# Index([u'toll_both', u'vehicle_no', u'loading_out_time', u'ist_timestamp',
#        u'distance_travelled', u'distance_travelled_cummulative',
#        u'time_of_travel', u'day_of_travel', u'month_of_travel',
#        u'days_from_now', u'delivery', u'time_taken', u'delay',
#        u'time_btn_tolls'],
#       dtype='object')

# %%
train_df.drop(['delivery','vehicle_no','ist_timestamp','distance_travelled_cummulative'], axis=1, inplace=True)
test_df.drop(['delivery','vehicle_no','ist_timestamp','distance_travelled_cummulative'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test_df.head()
# Out:
#                     toll_both loading_out_time  distance_travelled  \
# 561                  Sergrarh                1                0.00
# 739                 Panikholi                1               93.71
# 919                   Manguli                1               53.26
# 383  Gudipada (Old Gangapada)                1               56.30
# 199                 Gurapalli                1               88.58
#
#     time_of_travel day_of_travel month_of_travel days_from_now  time_taken  \
# 561             11             5               9            89   33.987222
# 739             15             5               9            89   38.447500
# 919             18             5               9            89   41.426944
# 383             20             5               9            89   43.580000
# 199             23             5               9            89   46.131667
#
#         delay  time_btn_tolls
# 561 -2.299028       33.987222
# 739 -2.596667        4.460278
# 919 -1.191944        2.979444
# 383 -0.745833        2.153056
# 199 -1.620556        2.551667

# %%
# toll.dtypes

# %%
# for truck in final_df.vehicle_no.unique().tolist():
#     final_df.loc[final_df['vehicle_no'] == truck, 'distance_travelled_cummulative'] = final_df.loc[final_df['vehicle_no'] == truck]['distance_travelled'].cumsum()

# %%
final_df.toll_both.nunique()
# Out:
# 21

# %%
final_df[final_df['vehicle_no'] == 'JH01AE6027']
# Out:
#                       toll_both  vehicle_no  loading_out_time  \
# 471                    Sergrarh  JH01AE6027                 0
# 830                     Manguli  JH01AE6027                 0
# 292    Gudipada (Old Gangapada)  JH01AE6027                 0
# 2082                  Bellupada  JH01AE6027                 0
# 2247                    Madapam  JH01AE6027                 0
# 1388               Chilakapalem  JH01AE6027                 0
# 2433  Nathavalasa/ Vizianagaram  JH01AE6027                 0
# 1570                    Vempadu  JH01AE6027                 0
# 1009               Krishnavaram  JH01AE6027                 0
# 1739                       Kaza  JH01AE6027                 0
# 3124                  Bolapalli  JH01AE6027                 0
# 3290                   Tangutur  JH01AE6027                 0
# 2953       Sunambatti (Musunur)  JH01AE6027                 0
# 1914                    Budanam  JH01AE6027                 0
# 3582                   Gaddurur  JH01AE6027                 0
# 3455                   Mulbagal  JH01AE6027                 0
# 440                    Sergrarh  JH01AE6027                 1
# 615                   Panikholi  JH01AE6027                 1
# 795                     Manguli  JH01AE6027                 1
# 1258   30.293056 -31.318889        1.845833
# 1617   36.127222 -32.685000        5.834167
# 1057   39.135833 -33.546667        3.008611
# 2832   44.340833 -35.024028        5.205000
# 2659   45.007500 -33.368611        0.666667
# 1791   46.211944 -34.446667        1.204444
# 3338   52.532222 -34.957917        6.320278
# 3000   54.152778 -35.562083        1.620556
# 1965   56.621111 -38.130694        2.468333
# 3620   76.676667 -35.040833       20.055556
# 3496   77.668889 -33.652500        0.992222

# %%
# dict_last_ist = {}

# # list_choice_truck = test_df.vehicle_no.unique().tolist()
# choice = True
# while(choice):
# #     num = 1
# #     print 'Choose the vehjcle no.'
    
# #     today_date = datetime.datetime.now()
# #     for truck in list_choice_truck:
# #         print str(num) + '  ' + truck
# #         num += 1
    
        
# #     vehicle = raw_input('Enter the vehicle no.: ')
# #     list_choice_truck.remove(vehicle)
    
    
#     loading_out = raw_input('Enter the loading out time in %Y-%m-%d %H:%M:%S format: ')
#     loading_out_delta = datetime.datetime.strptime(loading_out, '%Y-%m-%d %H:%M:%S')
    
    
#     print 'Enter the latest toll both details: '
    
#     b = []
#     toll = raw_input('Toll both: ')
# #     list_toll.append(toll)
#     distance = input('Distance travelled from previous toll in km: ')
#     ist = raw_input('IST Timestamp in %Y-%m-%d %H:%M:%S format: ')
#     ist_delta = datetime.datetime.strptime(ist, '%Y-%m-%d %H:%M:%S')
    
# #     ist_delta 
# #     b.extend([toll, vehicle, loading_out_delta.hour, ist_delta, distance, ist_delta.hour, ist_delta.weekday(), ist_delta.month,
# #                   (today_date - loading_out_delta).days, (ist_delta - loading_out_delta).total_seconds()/3600])
# #     a.append(b)
# #     dict_last_ist[vehicle] = ist_delta
# #     count+=1
    
    
# #     add_df = pd.DataFrame(a, columns= ['toll_both','vehicle_no','loading_out_time', 'ist_timestamp', 'distance_travelled', 'time_of_travel',
# #                                          'day_of_travel', 'month_of_travel', 'days_from_now', 'time_taken'])
    
# #     add_df['time_btn_tolls'] = add_df['time_taken'].diff()
# #     add_df = add_df.fillna(0)
# #     final_train_df = final_train_df.append(add_df)
    
# #     final_test_df = final_test_df[(final_test_df['vehicle_no'] != vehicle) | (final_test_df['toll_both'].isin(list_toll) == False)] 
    
    
    
# #     test_toll = raw_input('Enter the numbers of tolls the vehicle shall take in the journey SEQUENTIALLY: ')
# #     test_toll_list = test_toll.split(',')
# #     test_toll_list = [str(a) for a in test_toll_list]

# #     a = []

# #     for toll_val in test_toll_list:
# #         b = []
# #         distance = toll_time['distance_travelled'][toll_time.toll_both == toll_val].median()
# #         ist_delta = loading_out_delta + timedelta(hours=toll_time['time_taken'][toll_time.toll_both == toll_val].median())
# #         b.extend([toll_val, vehicle, loading_out_delta.hour, distance, ist_delta.hour, ist_delta.weekday(), ist_delta.month,
# #                       (today_date - loading_out_delta).days, (ist_delta - loading_out_delta).total_seconds()/3600])

# #         a.append(b)
# #     add_test_df = pd.DataFrame(a, columns= ['toll_both','vehicle_no','loading_out_time','distance_travelled', 'time_of_travel',
# #                                          'day_of_travel', 'month_of_travel', 'days_from_now','time_taken'])
    
# #     add_test_df['time_btn_tolls'] = add_test_df['time_taken'].diff()
# #     add_test_df = add_test_df.fillna(0)
    
# #     test_df = test_df.append(add_test_df)
    
# #     c = raw_input('Want to enter more vehicles?(y/n)')
    
# #     if (c == 'y' or c == 'Y'):
# #         continue
# #     elif (c == 'n' or c == 'N'):
# #         choice = False
# #         print 'bbye'
# #     else:
# #         print 'Wrong Choice! Exiting'
# #         choice = False

# %%
# train_df.shape, test_df.shape, final_train_df.shape, final_test_df.shape

# %%
# final_train_df.loc[final_train_df['time_btn_tolls'] == 0, 'time_btn_tolls']  = final_train_df.loc[final_train_df['time_btn_tolls'] == 0, 'time_taken']

# %%
def find_toll_num(df):
    toll_dict = {}
    new_toll_dict = {}
    x = {}
    num = 1
    for toll in df.toll_both.unique().tolist():
        t = df['time_taken'][df.toll_both == toll].median()
        toll_dict[toll] = t
    
    for key, value in sorted(toll_dict.iteritems(), key=lambda (k,v): (v,k)):
        x[key] = value
        new_toll_dict[key] = num
        num+=1
        
    return new_toll_dict, x

# %%
new_toll_dict,x = find_toll_num(train_df)

# %%
# dict_toll_both_train_df = change_toll_booth_to_dummy(train_df)
train_df.toll_both = train_df.toll_both.replace(new_toll_dict)
test_df.toll_both = test_df.toll_both.replace(new_toll_dict)

# %%
final_test_copy = test_df.copy()
final_train_copy = train_df.copy()
test_df
# Out:
#       toll_both loading_out_time  distance_travelled time_of_travel  \
# 561           1                1                0.00             11
# 739           2                1               93.71             15
# 919           3                1               53.26             18
# 383           4                1               56.30             20
# 199           5                1               88.58             23
# 2159          6                1               83.91              3
# 2335          7                1              116.37              8
# 1475          8                1               26.47              9
# 2518         10                1               39.33             12
# 1655         11                1              132.47             17
# 1094         12                1               69.22             19
# 2868         14                1              144.61              1
# 2695         13                1               21.91              2
# 1827         15                1               45.08              3
# 3209         16                1               82.52              5
# 3374         17                1               64.45              6
# 3036         18                1               61.42              8
# 2001         19                1               96.99             12
# 3646         21                1              216.50             20
# 3521         20                1               30.61             21
#
#      day_of_travel month_of_travel days_from_now  time_taken      delay  \
# 561              5               9            89   33.987222  -2.299028
# 739              5               9            89   38.447500  -2.596667
# 919              5               9            89   41.426944  -1.191944
# 383              5               9            89   43.580000  -0.745833
# 199              5               9            89   46.131667  -1.620556
# 2159             5               9            89   50.111111  -4.525278
# 2335             5               9            89   55.362222  -3.549444
# 1475             5               9            89   56.087778  -4.153056
# 2518             5               9            89   59.095278  -2.910556
# 1655             5               9            89   88.823333  20.011111
# 1094             5               9            89   90.854444  18.171944
# 2868             5               9            89   96.244444  16.879583
# 2695             5               9            89   96.939167  18.563056
# 1827             5               9            89   98.155833  17.497222
# 3209             5               9            89  100.191944  14.996389
# 3374             5               9            89  101.836667  14.346528
# 3036             5               9            89  103.404722  13.689861
# 2001             5               9            89  107.123056  12.371250
# 3646             5               9            89  115.726944   4.009444
# 3521             5               9            89  116.761111   5.439722
#
#       time_btn_tolls
# 561        33.987222
# 739         4.460278
# 919         2.979444
# 383         2.153056
# 199         2.551667
# 2159        3.979444
# 2335        5.251111
# 1475        0.725556
# 2518        3.007500
# 1655       29.728056
# 1094        2.031111
# 2868        5.390000
# 2695        0.694722
# 1827        1.216667
# 3209        2.036111
# 3374        1.644722
# 3036        1.568056
# 2001        3.718333
# 3646        8.603889
# 3521        1.034167

# %%
corr = train_df.corr()
corr
# sns.heatmap(corr, 
#         xticklabels=corr.columns,
#         yticklabels=corr.columns)
# Out:
#                     toll_both  loading_out_time  distance_travelled  \
# toll_both            1.000000         -0.017663            0.278424
# loading_out_time    -0.017663          1.000000           -0.001258
# distance_travelled   0.278424         -0.001258            1.000000
# time_of_travel      -0.009646         -0.005372           -0.017908
# day_of_travel        0.009282         -0.112795            0.010039
# month_of_travel      0.002456          0.013385            0.024914
# days_from_now       -0.006890         -0.002831           -0.025558
# delay                0.048321         -0.031590            0.007025
# time_btn_tolls      -0.211599         -0.008101           -0.038523
#
#                     time_of_travel  day_of_travel  month_of_travel  \
# toll_both                -0.009646       0.009282         0.002456
# loading_out_time         -0.005372      -0.112795         0.013385
# distance_travelled       -0.017908       0.010039         0.024914
# time_of_travel            1.000000      -0.012585         0.026595
# day_of_travel            -0.012585       1.000000         0.016381
# month_of_travel           0.026595       0.016381         1.000000
# days_from_now            -0.031003      -0.001992        -0.948081
# delay                     0.074592      -0.032439         0.070294
# time_btn_tolls            0.102234      -0.016259         0.024212
#
#                     days_from_now     delay  time_btn_tolls
# toll_both               -0.006890  0.048321       -0.211599
# loading_out_time        -0.002831 -0.031590       -0.008101
# distance_travelled      -0.025558  0.007025       -0.038523
# time_of_travel          -0.031003  0.074592        0.102234
# day_of_travel           -0.001992 -0.032439       -0.016259
# month_of_travel         -0.948081  0.070294        0.024212
# days_from_now            1.000000 -0.081478       -0.021612
# delay                   -0.081478  1.000000        0.204787
# time_btn_tolls          -0.021612  0.204787        1.000000

# %%
# def change_vehicle_no_to_dummy(df):
#     num = 1
#     dict_vehicle_no = {}
#     for truck in df['vehicle_no'].unique().tolist():
#         df['vehicle_no'] = df['vehicle_no'].replace({truck: num})
#         dict_vehicle_no[num] = truck
#         num += 1
#     return dict_vehicle_no

# %%
# dict_vehicle_no_train_df = change_vehicle_no_to_dummy(final_train_df)
# rev_dict_vehicle_no_test_df = dict((v,k) for k,v in dict_vehicle_no_train_df.iteritems())
# final_test_df.vehicle_no = final_test_df.vehicle_no.replace(rev_dict_vehicle_no_test_df)

# %%
# ist_test = final_test_df['ist_timestamp']
# final_train_df_copy = final_train_df.copy()
# final_test_df_copy = final_test_df.copy()

# %%
# final_train_df.drop(['ist_timestamp','time_taken'], axis=1, inplace=True)
# final_test_df.drop(['ist_timestamp','time_taken','time_btn_tolls'], axis=1, inplace=True)

# %%
train_df.drop(['time_taken'], axis=1, inplace=True)
test_df.drop(['time_taken'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# %%
train_X = train_df.drop(['time_btn_tolls'], axis=1)
train_y = train_df.time_btn_tolls

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X,train_y, test_size=0.3, random_state=42)

# %%
scale= MinMaxScaler()
X_train_scaled = scale.fit_transform(X_train)
X_test_scaled = scale.fit_transform(X_test)

# %%
reg_mlp = MLPRegressor(hidden_layer_sizes=(200,40), activation='logistic', alpha=8, solver='lbfgs', random_state=42)

# %%
# reg_svr = SVR(C=100.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=1.0,
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
reg_mlp.fit(X_train_scaled, y_train)
reg_mlp.score(X_test_scaled, y_test)
# Out:
# 0.62554210319533188

# %%
scores = cross_val_score(reg_mlp, X_train_scaled, y_train, scoring='r2', n_jobs=-1)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.79 (+/- 0.16)

# %%
scale = MinMaxScaler()
test_X = train_df.drop(['time_btn_tolls'], axis=1)
X_predict_scaled = scale.fit_transform(test_X)
predictions = reg_mlp.predict(X_predict_scaled)

# %%
show_df = train_df.copy()
show_df['predicted'] = predictions

# %%
# show_df['predicted_timestamp']

# %%
# show_df_copy = show_df.copy()
show_df = show_df.reset_index(drop=True)

# %%
show_df
# Out:
#       toll_both  loading_out_time  distance_travelled  time_of_travel  \
# 0             1                 0                0.00              13
# 1             3                 0              146.47              20
# 2             4                 0               55.83              22
# 3             6                 0              171.77               6
# 4             7                 0              114.17              13
# 5             8                 0               27.46              14
# 6            10                 0               38.72              19
# 7            11                 0               67.28              11
# 8            12                 0               69.42              16
# 9            15                 0              209.57              23
# 10           16                 0               82.18               1
# 11           17                 0               63.96               3
# 12           18                 0               62.31              10
# 13           19                 0               97.26              12
# 14           21                 0              215.25              21
# 15           20                 0               30.89              22
# 16            1                 1                0.00              18
# 17            2                 1               92.99              21
# 18            3                 1               54.27              22
# 19            5                 1               77.86               3
# 20            6                 1               84.43               6
# 21           14                 1              144.56               1
# 22           13                 1               21.60               1
# 23           15                 1               45.56               2
# 24            1                 9                0.00              18
# 25            2                 9               93.80              21
# 26            3                 9               53.36              23
# 27            4                 9               56.74               0
# 28            5                 9               87.69               3
# 29            6                 9               83.42               8
# ...         ...               ...                 ...             ...
# 3278          8                 4               27.06              18
# 3279          9                 4               39.70              19
# 3280         14                 4              170.34              12
# 3281         13                 4               21.93              13
# 3282         15                 4               44.66              14
# 3283         16                 4               82.67              17
# 3284         17                 4               63.96              19
# 3285         19                 4              110.44               7
# 3286         21                 4              219.14              17
# 3287         20                 4               30.14              18
# 3288          1                 1                0.00              20
# 3289          2                 1               93.46              22
# 3290          3                 1               48.22               0
# 3291          6                 1               81.15               6
# 3292          8                 1               36.62              11
# 3293          9                 1               39.06              12
# 3294         15                 1              107.17              13
# 3295          1                 5                0.00              20
# 3296          6                 5              160.22              18
# 3297          7                 5               99.24              23
# 3298          8                 5               10.07              23
# 3299          9                 5                6.11               2
# 3300          6                 3                0.00              13
# 3301         12                 3               11.60              13
# 3302         21                 3               41.43              14
# 3303         20                 3               30.78              15
# 3304         11                23                0.00              15
# 3305         12                23               70.03              17
# 3306         14                23              146.31               0
# 3307         13                23               21.61               0
#
#       day_of_travel  month_of_travel  days_from_now      delay  \
# 0                 2               11             44  49.392083
# 1                 2               11             44  49.692778
# 2                 2               11             44  50.178056
# 3                 2               11             44  47.963889
# 4                 2               11             44  50.314722
# 5                 2               11             44  49.641944
# 6                 2               11             44  53.543611
# 7                 2               11             44  61.925556
# 8                 2               11             44  63.340278
# 9                 2               11             44  62.708889
# 10                2               11             44  60.510000
# 11                2               11             44  59.966250
# 12                2               11             44  64.157639
# 13                2               11             44  61.315972
# 14                2               11             44  53.598889
# 15                2               11             44  54.965000
# 16                4               12             20   4.860139
# 17                4               12             20   2.538333
# 18                4               12             20   2.266389
# 19                4               12             20   1.934444
# 20                4               12             20  -1.676667
# 21                4               12             20  -7.751528
# 22                4               12             20  -6.196111
# 23                4               12             20  -7.292500
# 24                2               10             71 -27.560139
# 25                2               10             71 -29.565000
# 26                2               10             71 -29.236667
# 27                2               10             71 -29.057222
# 28                2               10             71 -29.844444
# 29                2               10             71 -31.993333
# ...             ...              ...            ...        ...
# 3278              5               11             47   1.760556
# 3279              5               11             47   1.399722
# 3280              5               11             47   0.593194
# 3281              5               11             47   2.548611
# 3282              5               11             47   1.440000
# 3283              5               11             47   0.125000
# 3284              5               11             47  -0.530694
# 3285              5               11             47   4.230417
# 3286              5               11             47  -2.200278
# 3287              5               11             47  -0.725833
# 3288              1               10             57 -17.504028
# 3289              1               10             57 -20.109167
# 3290              1               10             57 -19.703333
# 3291              1               10             57 -25.640833
# 3292              1               10             57 -26.605278
# 3293              1               10             57 -26.628889
# 3294              1               10             57   3.212222
# 3295              4               10             80  50.040417
# 3296              4               10             80  53.799444
# 3297              4               10             80  54.216111
# 3298              4               10             80  53.560833
# 3299              4               10             80  55.113333
# 3300              1               12             16  27.478333
# 3301              1               12             16  33.049722
# 3302              1               12             16  19.207778
# 3303              1               12             16  20.408333
# 3304              3               11             29  -5.029167
# 3305              3               11             29  -7.363056
# 3306              3               11             29  -6.916250
# 3307              3               11             29  -5.444167
#
#       time_btn_tolls  predicted
# 0          85.678333  79.424443
# 1           6.633333   9.058638
# 2           2.192222   3.929584
# 3           8.096389  11.229275
# 4           6.626111   6.957125
# 5           0.656389   5.643796
# 6           5.666667   3.148340
# 7          12.783056   4.156992
# 8           5.285000   4.463077
# 9           7.344722  13.705155
# 10          2.338056   5.999428
# 11          1.750833   4.710102
# 12          6.416111   4.838174
# 13          2.195278   7.564973
# 14          9.248611  13.232890
# 15          0.970000   2.850539
# 16         41.146389  43.624118
# 17          2.436111   3.161566
# 18          1.302778   1.994025
# 19          4.801389   2.643290
# 20          3.273056   2.979147
# 21         18.653611   6.829723
# 22          0.566667   1.037793
# 23          1.186111   1.512895
# 24          8.726111  15.007691
# 25          2.753056   2.805163
# 26          1.903056   1.442524
# 27          1.886389   1.460443
# 28          2.639167   2.694589
# 29          4.735278   2.477924
# ...              ...        ...
# 3278        0.789444   1.688541
# 3279        1.010278   1.578017
# 3280       16.946389   8.859971
# 3281        0.966667   1.262820
# 3282        1.173889   1.745513
# 3283        3.221944   3.732057
# 3284        1.638889   2.727866
# 3285       12.022778   5.595019
# 3286       10.535000  11.158757
# 3287        1.078333   1.266641
# 3288       18.782222  21.931675
# 3289        2.152778   3.115789
# 3290        1.980556   1.649695
# 3291        6.080000   2.633042
# 3292        4.640000   1.168866
# 3293        1.347500   1.175162
# 3294       48.887778   5.744801
# 3295       86.326667  78.328525
# 3296       22.109167  10.567900
# 3297        4.691944   5.685735
# 3298        0.673889  17.301258
# 3299        2.923611  19.203884
# 3300       82.114722  28.410127
# 3301       23.617500   3.285103
# 3302       25.193056   2.608119
# 3303        0.804444   2.069371
# 3304       63.783056   2.004519
# 3305        1.536389   2.956422
# 3306        7.129167   7.645723
# 3307        0.483333   1.246731
#
# [3308 rows x 10 columns]

# %%
new_toll_dict['Laxmipuram']
# Out:
# 9

# %%
show_df.index[show_df['toll_both'] == 10][0]
# Out:
# 8

# %%
dict_last_ist = {}

# list_choice_truck = test_df.vehicle_no.unique().tolist()

loading_out = raw_input('Enter the loading out time in %Y-%m-%d %H:%M:%S format: ')
loading_out_delta = datetime.datetime.strptime(loading_out, '%Y-%m-%d %H:%M:%S')

show_df['predicted_ist'] = show_df['predicted'].apply(lambda x: datetime.timedelta(hours=x))
show_df['predicted_ist'] = show_df['predicted_ist'].cumsum()
show_df['predicted_ist'] = show_df['predicted_ist'].apply(lambda x: x+ loading_out_delta)
show_df['predict']
    
choice = True
while(choice):
    
    
    print 'Enter the latest toll both details: '
    
    b = []
    toll = raw_input('Toll both: ')
#     list_toll.append(toll)
    distance = input('Distance travelled from previous toll in km: ')
    ist = raw_input('IST Timestamp in %Y-%m-%d %H:%M:%S format: ')
    ist_delta = datetime.datetime.strptime(ist, '%Y-%m-%d %H:%M:%S')
    
    i = show_df.index[show_df['toll_both'] == new_toll_dict[toll]][0]
    
    final_show_df = show_df[i+1:]
    
    final_show_df['predicted_ist'] = final_show_df['predicted'].apply(lambda x: datetime.timedelta(hours=x))
    final_show_df['predicted_ist'] = final_show_df['predicted_ist'].cumsum()
    final_show_df['predicted_ist'] = final_show_df['predicted_ist'].apply(lambda x: x + ist_delta)
    
    final_show_df    
    
#     ist_delta 
#     b.extend([toll, vehicle, loading_out_delta.hour, ist_delta, distance, ist_delta.hour, ist_delta.weekday(), ist_delta.month,
#                   (today_date - loading_out_delta).days, (ist_delta - loading_out_delta).total_seconds()/3600])
#     a.append(b)
#     dict_last_ist[vehicle] = ist_delta
#     count+=1
    
    
#     add_df = pd.DataFrame(a, columns= ['toll_both','vehicle_no','loading_out_time', 'ist_timestamp', 'distance_travelled', 'time_of_travel',
#                                          'day_of_travel', 'month_of_travel', 'days_from_now', 'time_taken'])
    
#     add_df['time_btn_tolls'] = add_df['time_taken'].diff()
#     add_df = add_df.fillna(0)
#     final_train_df = final_train_df.append(add_df)
    
#     final_test_df = final_test_df[(final_test_df['vehicle_no'] != vehicle) | (final_test_df['toll_both'].isin(list_toll) == False)] 
    
    c = raw_input('Want to enter more vehicles?(y/n)')
    
    if (c == 'y' or c == 'Y'):
        continue
    elif (c == 'n' or c == 'N'):
        choice = False
        print 'bbye'
    else:
        print 'Wrong Choice! Exiting'
        choice = False
# Out:
# Enter the loading out time in %Y-%m-%d %H:%M:%S format: 2017-11-03 12:02:43
# Enter the latest toll both details:
# Toll both: Manguli
# Distance travelled from previous toll in km: 54
# IST Timestamp in %Y-%m-%d %H:%M:%S format: 2017-11-04 12:10:12
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Want to enter more vehicles?(y/n)n
# bbye

# %%
final_show_df['time_taken'] = final_show_df['time_btn_tolls'].cumsum()
final_show_df['predicted_time_taken'] = final_show_df['predicted'].cumsum()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
final_show_df
# Out:
#     toll_both loading_out_time  distance_travelled time_of_travel  \
# 3           4                1               56.30             20
# 4           5                1               88.58             23
# 5           6                1               83.91              3
# 6           7                1              116.37              8
# 7           8                1               26.47              9
# 8          10                1               39.33             12
# 9          11                1              132.47             17
# 10         12                1               69.22             19
# 11         14                1              144.61              1
# 12         13                1               21.91              2
# 13         15                1               45.08              3
# 14         16                1               82.52              5
# 15         17                1               64.45              6
# 16         18                1               61.42              8
# 17         19                1               96.99             12
# 18         21                1              216.50             20
# 19         20                1               30.61             21
#
#    day_of_travel month_of_travel days_from_now      delay  time_btn_tolls  \
# 3              5               9            89  -0.745833        2.153056
# 4              5               9            89  -1.620556        2.551667
# 5              5               9            89  -4.525278        3.979444
# 6              5               9            89  -3.549444        5.251111
# 7              5               9            89  -4.153056        0.725556
# 8              5               9            89  -2.910556        3.007500
# 9              5               9            89  20.011111       29.728056
# 10             5               9            89  18.171944        2.031111
# 11             5               9            89  16.879583        5.390000
# 12             5               9            89  18.563056        0.694722
# 13             5               9            89  17.497222        1.216667
# 14             5               9            89  14.996389        2.036111
# 15             5               9            89  14.346528        1.644722
# 16             5               9            89  13.689861        1.568056
# 17             5               9            89  12.371250        3.718333
# 18             5               9            89   4.009444        8.603889
# 19             5               9            89   5.439722        1.034167
#
#     predicted              predicted_ist  time_taken  predicted_time_taken
# 3    6.760934 2017-11-04 18:55:51.363232    2.153056              6.760934
# 4   10.818146 2017-11-05 05:44:56.687710    4.704722             17.579080
# 5    8.757234 2017-11-05 14:30:22.730852    8.684167             26.336314
# 6   12.132454 2017-11-06 02:38:19.564165   13.935278             38.468768
# 7    1.750225 2017-11-06 04:23:20.375569   14.660833             40.218993
# 8    3.827296 2017-11-06 08:12:58.640336   17.668333             44.046289
# 9   17.245037 2017-11-07 01:27:40.773649   47.396389             61.291326
# 10  16.034894 2017-11-07 17:29:46.393474   49.427500             77.326220
# 11  16.524288 2017-11-08 10:01:13.831940   54.817500             93.850509
# 12  30.266520 2017-11-09 16:17:13.302659   55.512222            124.117029
# 13  12.945335 2017-11-10 05:13:56.510138   56.728889            137.062364
# 14  16.250925 2017-11-10 21:28:59.840970   58.765000            153.313289
# 15  15.072463 2017-11-11 12:33:20.707229   60.409722            168.385752
# 16  14.651453 2017-11-12 03:12:25.937511   61.977778            183.037205
# 17  15.865390 2017-11-12 19:04:21.341430   65.696111            198.902595
# 18  13.648544 2017-11-13 08:43:16.098766   74.300000            212.551139
# 19   6.560422 2017-11-13 15:16:53.616344   75.334167            219.111560

# %%
# for num, truck in dict_vehicle_no_train_df.iteritems():
list_truck = []
for truck, ist in dict_last_ist.iteritems():
    list_truck.append(truck)
    
for truck in list_truck:
    i = rev_dict_vehicle_no_test_df[truck]
    dict_last_ist[i] = dict_last_ist.pop(truck)

# %%
dict_last_ist
# Out:
# {128: datetime.datetime(2017, 11, 4, 12, 10, 12),
#  129: datetime.datetime(2017, 10, 4, 20, 40, 53),
#  130: datetime.datetime(2017, 11, 23, 22, 15, 25)}

# %%
show_df['eta'] = show_df['predicted']

# %%
dict_last_ist
# Out:
# {'BR02GA0735': datetime.datetime(2017, 11, 4, 12, 10, 12),
#  'JH02M1289': datetime.datetime(2017, 11, 23, 22, 15, 25),
#  'TN28BB9075': datetime.datetime(2017, 10, 4, 20, 40, 53)}

# %%
show_df['time_taken'] = 0
for truck, ist in dict_last_ist.iteritems():
    show_df.loc[show_df['vehicle_no'] == truck, 'time_taken'] = show_df['predicted'][show_df['vehicle_no'] == truck].cumsum()

# %%
for truck, ist in dict_last_ist.iteritems():
    show_df['eta'][show_df['vehicle_no'] == truck] = str(ist)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
show_df['eta'] = show_df['eta'].apply(lambda x:datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S') )

# %%
show_df.dtypes
# Out:
# toll_both                      int64
# vehicle_no                     int64
# loading_out_time              object
# distance_travelled           float64
# time_of_travel                object
# day_of_travel                 object
# month_of_travel               object
# days_from_now                 object
# predicted                    float64
# eta                   datetime64[ns]
# time_taken                   float64
# dtype: object

# %%
show_df['time_taken'] = show_df['time_taken'].apply(lambda x: datetime.timedelta(hours=x) )

# %%
show_df['eta'] = show_df['eta'] + show_df['time_taken']

# %%
show_df['vehicle_no'] = show_df['vehicle_no'].apply(lambda x:dict_vehicle_no_train_df[x])

# %%
rev_toll_dict = dict((v,k) for k,v in new_toll_dict.iteritems())
show_df.toll_both = show_df.toll_both.replace(rev_toll_dict)

# %%
show_df
# Out:
#                       toll_both  vehicle_no loading_out_time  \
# 383    Gudipada (Old Gangapada)  BR02GA0735                1
# 199                   Gurapalli  BR02GA0735                1
# 2159                  Bellupada  BR02GA0735                1
# 2335                    Madapam  BR02GA0735                1
# 1475               Chilakapalem  BR02GA0735                1
# 2518  Nathavalasa/ Vizianagaram  BR02GA0735                1
# 1655                    Vempadu  BR02GA0735                1
# 1094               Krishnavaram  BR02GA0735                1
# 2868                  Kalaparru  BR02GA0735                1
# 2695                  Pottipadu  BR02GA0735                1
# 1827                       Kaza  BR02GA0735                1
# 3209                  Bolapalli  BR02GA0735                1
# 3374                   Tangutur  BR02GA0735                1
# 3036       Sunambatti (Musunur)  BR02GA0735                1
# 2001                    Budanam  BR02GA0735                1
# 3646                   Gaddurur  BR02GA0735                1
# 3521                   Mulbagal  BR02GA0735                1
# 886                     Manguli  TN28BB9075               14
# 350    Gudipada (Old Gangapada)  TN28BB9075               14
# 166                   Gurapalli  TN28BB9075               14
# 2129                  Bellupada  TN28BB9075               14
# 2302                    Madapam  TN28BB9075               14
# 1444               Chilakapalem  TN28BB9075               14
# 1264                 Laxmipuram  TN28BB9075               14
# 1623                    Vempadu  TN28BB9075               14
# 1063               Krishnavaram  TN28BB9075               14
# 2838                  Kalaparru  TN28BB9075               14
# 2665                  Pottipadu  TN28BB9075               14
# 1797                       Kaza  TN28BB9075               14
# 3178                  Bolapalli  TN28BB9075               14
# ...                         ...         ...              ...
# 1176                 Laxmipuram   JH02M1289               23
# 1534                    Vempadu   JH02M1289               23
# 975                Krishnavaram   JH02M1289               23
# 2746                  Kalaparru   JH02M1289               23
# 2575                  Pottipadu   JH02M1289               23
# 1705                       Kaza   JH02M1289               23
# 3090                  Bolapalli   JH02M1289               23
# 3260                   Tangutur   JH02M1289               23
# 2919       Sunambatti (Musunur)   JH02M1289               23
# 1881                    Budanam   JH02M1289               23
# 3554                   Gaddurur   JH02M1289               23
# 3427                   Mulbagal   JH02M1289               23
# 907                     Manguli   JH02M1289                5
# 371    Gudipada (Old Gangapada)   JH02M1289                5
# 187                   Gurapalli   JH02M1289                5
# 2146                  Bellupada   JH02M1289                5
# 2322                    Madapam   JH02M1289                5
# 1462               Chilakapalem   JH02M1289                5
# 1284                 Laxmipuram   JH02M1289                5
# 1643                    Vempadu   JH02M1289                5
# 1083               Krishnavaram   JH02M1289                5
# 2858                  Kalaparru   JH02M1289                5
# 2685                  Pottipadu   JH02M1289                5
# 1817                       Kaza   JH02M1289                5
# 3198                  Bolapalli   JH02M1289                5
# 3364                   Tangutur   JH02M1289                5
# 3026       Sunambatti (Musunur)   JH02M1289                5
# 1991                    Budanam   JH02M1289                5
# 3637                   Gaddurur   JH02M1289                5
# 3512                   Mulbagal   JH02M1289                5
#
#       distance_travelled time_of_travel day_of_travel month_of_travel  \
# 383                56.30             20             5               9
# 199                88.58             23             5               9
# 2159               83.91              3             5               9
# 2335              116.37              8             5               9
# 1475               26.47              9             5               9
# 2518               39.33             12             5               9
# 1655              132.47             17             5               9
# 1094               69.22             19             5               9
# 2868              144.61              1             5               9
# 2695               21.91              2             5               9
# 1827               45.08              3             5               9
# 3209               82.52              5             5               9
# 3374               64.45              6             5               9
# 3036               61.42              8             5               9
# 2001               96.99             12             5               9
# 3646              216.50             20             5               9
# 3521               30.61             21             5               9
# 886                53.72             17             0              10
# 350                56.40             19             0              10
# 166                87.66             21             0              10
# 2129               84.93              1             0              10
# 2302              115.83              4             0              10
# 1444               26.86              4             0              10
# 1264               40.56              5             0              10
# 1623              127.77              9             0              10
# 1063               70.14             11             0              10
# 2838              143.97             15             0              10
# 2665               21.39             16             0              10
# 1797               45.45             17             0              10
# 3178               82.33             20             0              10
# ...                  ...            ...           ...             ...
# 1176               40.00             14             5              12
# 1534              128.86             23             5              12
# 975                70.21             10             5              12
# 2746              141.13             20             5              12
# 2575               21.34             20             5              12
# 1705               45.66             22             5              12
# 3090               79.83              6             5              12
# 3260               63.89              7             5              12
# 2919               62.41              9             5              12
# 1881               97.18             12             5              12
# 3554              215.33             22             5              12
# 3427               30.54             23             5              12
# 907                53.86             20             0              10
# 371                55.66              7             0              10
# 187                89.76             12             0              10
# 2146               83.69             17             0              10
# 2322              116.17             21             0              10
# 1462               26.60              0             0              10
# 1284               40.10              1             0              10
# 1643              133.20             14             0              10
# 1083               70.12             16             0              10
# 2858               50.91             23             0              10
# 2685               21.36              0             0              10
# 1817               45.75              1             0              10
# 3198               81.92              3             0              10
# 3364               63.93              8             0              10
# 3026               62.25             10             0              10
# 1991               98.52             12             0              10
