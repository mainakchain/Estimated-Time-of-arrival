# %%
import sqlite3
import numpy as np
import mysql.connector
import pandas as pd
import getpass
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
plotly.tools.set_credentials_file(username='mainakchain', api_key='B9m4DVrYYmsoW3jDSiok')
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
import plotly.figure_factory as ff
from scipy import stats
from sklearn.utils import shuffle
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from datetime import timedelta
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
toll_time = pd.read_csv('toll_time.csv')

# %%
toll_time.columns
# Out:
# Index([u'Unnamed: 0', u'origin', u'destination', u'toll_both', u'vehicle_no',
#        u'loading_out_time', u'odometer_km', u'ist_timestamp',
#        u'distance_from_toll', u'loading_in_time', u'start_date', u'eta',
#        u'unloading_in_time', u'slug', u'delivery_status',
#        u'distance_travelled', u'late_by_hrs', u'time_taken'],
#       dtype='object')

# %%
new_toll_time = toll_time[toll_time['origin'] == 'Dhenkanal'][toll_time['destination'] == 'Visakhapatnam']
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
new_toll_time = new_toll_time[['toll_both','vehicle_no','delivery_status','distance_travelled','late_by_hrs','time_taken']]

# %%
new_toll_time['delivery_status'] = new_toll_time['delivery_status'].replace({'early':1,'on-time':2,'late':3})

# %%
new_toll_time['vehicle_no'].unique()
# Out:
# array(['AP05TA9595', 'AP05TD6769', 'AP05TG1315', 'AP05V7856', 'AP16TE6019',
#        'AP16TG9159', 'AP16TY8489', 'AP31TB4579', 'AP31TC0679',
#        'AP31TE8359', 'AP31TE8739', 'AP31TG1179', 'AP31TH5279',
#        'AP31TW4459', 'OD05AD2545', 'OD05AD7040', 'OD05AE7115',
#        'OD05AF2711', 'OD05C9095', 'OD05E2545', 'OD06A0121', 'OD19C7055',
#        'OD19J1122', 'OD19J9951', 'OD25C6067', 'OR04L0172', 'OR05AG0121',
#        'OR05AG3675', 'OR05AL5559', 'OR05Y0479', 'OR09D8796', 'OR09F4337',
#        'OR09L2312', 'OR15S5392', 'OR19B9500', 'OR19F6861', 'OR19F9475',
#        'OR19G5229', 'OR19K0729', 'OR19P7575', 'AP05TA4138', 'AP30W4599',
#        'OR19M1877', 'AP05TU8779'], dtype=object)

# %%
new_toll_time['toll_both'].value_counts()
# Out:
# Gurapalli                                   48
# Gudipada (Old Gangapada)                    48
# Nathavalasa/ Vizianagaram                   47
# Chilakapalem                                47
# Laxmipuram                                  47
# Madapam                                     46
# Bellupada                                   44
# Main Toll (Gosthani Gate) (Sheela Nagar)    40
# Name: toll_both, dtype: int64

# %%
new_toll_time['distance_travelled'][new_toll_time['toll_both'] == 'Chilakapalem'].min()
# Out:
# 296.98000000000002

# %%
new_toll_time['distance_travelled'][new_toll_time['vehicle_no' == 'OD05E2545']][new_toll_time['toll_both'] == 'Chilakapalem']
# Out:
#                      toll_both  vehicle_no  delivery_status  \
# 526                  Bellupada  AP05TA9595                1
# 527                  Bellupada  AP05TD6769                1
# 528                  Bellupada  AP05TG1315                1
# 529                  Bellupada   AP05V7856                1
# 530                  Bellupada  AP16TE6019                1
# 531                  Bellupada  AP16TG9159                1
# 532                  Bellupada  AP16TY8489                2
# 533                  Bellupada  AP31TB4579                1
# 534                  Bellupada  AP31TC0679                1
# 535                  Bellupada  AP31TE8359                2
# 536                  Bellupada  AP31TE8739                2
# 537                  Bellupada  AP31TG1179                1
# 538                  Bellupada  AP31TG1179                1
# 539                  Bellupada  AP31TH5279                1
# 540                  Bellupada  AP31TW4459                1
# ...

# %%
new_toll_time_copy = new_toll_time.copy()

# %%
new_toll_time['vehicle_no'].unique()
# Out:
# array(['AP05TA9595', 'AP05TD6769', 'AP05TG1315', 'AP05V7856', 'AP16TE6019',
#        'AP16TG9159', 'AP16TY8489', 'AP31TB4579', 'AP31TC0679',
#        'AP31TE8359', 'AP31TE8739', 'AP31TG1179', 'AP31TH5279',
#        'AP31TW4459', 'OD05AD2545', 'OD05AD7040', 'OD05AE7115',
#        'OD05AF2711', 'OD05C9095', 'OD05E2545', 'OD06A0121', 'OD19C7055',
#        'OD19J1122', 'OD19J9951', 'OD25C6067', 'OR04L0172', 'OR05AG0121',
#        'OR05AG3675', 'OR05AL5559', 'OR05Y0479', 'OR09D8796', 'OR09F4337',
#        'OR09L2312', 'OR15S5392', 'OR19B9500', 'OR19F6861', 'OR19F9475',
#        'OR19G5229', 'OR19K0729', 'OR19P7575', 'AP05TA4138', 'AP30W4599',
#        'OR19M1877', 'AP05TU8779'], dtype=object)

# %%
#Gurapalli

# %%
for truck in new_toll_time['vehicle_no'].unique().tolist():
    new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Gurapalli'] = new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Gurapalli'] - new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Gudipada (Old Gangapada)']

# %%
#Bellupada

# %%
lis_truck = []
for truck in new_toll_time['vehicle_no'].unique().tolist():
    if ((new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada'].shape[0] >= 1) and (new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Gurapalli'].shape[0] >= 1 )):
        new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada'] = new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada'] - new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Gurapalli']
    else:
        lis_truck.append(truck)

for truck in lis_truck:
    new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada'] = new_toll_time['distance_travelled'][new_toll_time['toll_both'] == 'Bellupada'].median()

# %%
lis_truck = []
for truck in new_toll_time['vehicle_no'].unique().tolist():
    if ((new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada'].shape[0] >= 1) and (new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Gurapalli'].shape[0] >= 1 )):
        new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada'] = new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada'] - new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Gurapalli']
    else:
        lis_truck.append(truck)

for truck in lis_truck:
    new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada'] = new_toll_time['time_taken'][new_toll_time['toll_both'] == 'Bellupada'].median()

# %%
#madapam

# %%
lis_truck = []
for truck in new_toll_time['vehicle_no'].unique().tolist():
    if ((new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada'].shape[0] >= 1) and (new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam'].shape[0] >= 1 )):
        new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam'] = new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam'] - new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada']
    else:
        lis_truck.append(truck)

for truck in lis_truck:
    new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam'] = new_toll_time['distance_travelled'][new_toll_time['toll_both'] == 'Madapam'].median()

# %%
lis_truck = []
for truck in new_toll_time['vehicle_no'].unique().tolist():
    if ((new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada'].shape[0] >= 1) and (new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam'].shape[0] >= 1 )):
        new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam'] = new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam'] - new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Bellupada']
    else:
        lis_truck.append(truck)

for truck in lis_truck:
    new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam'] = new_toll_time['time_taken'][new_toll_time['toll_both'] == 'Madapam'].median()

# %%
#chilakapelam

# %%
lis_truck = []
for truck in new_toll_time['vehicle_no'].unique().tolist():
    if ((new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem'].shape[0] >= 1) and (new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam'].shape[0] >= 1 )):
        new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem'] = new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem'] - new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam']
    else:
        lis_truck.append(truck)

for truck in lis_truck:
    new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem'] = new_toll_time['distance_travelled'][new_toll_time['toll_both'] == 'Chilakapalem'].median()

# %%
lis_truck = []
for truck in new_toll_time['vehicle_no'].unique().tolist():
    if ((new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem'].shape[0] >= 1) and (new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam'].shape[0] >= 1 )):
        new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem'] = new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem'] - new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Madapam']
    else:
        lis_truck.append(truck)

for truck in lis_truck:
    new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem'] = new_toll_time['distance_travelled'][new_toll_time['toll_both'] == 'Chilakapalem'].median()

# %%
#laxmipuram

# %%
lis_truck = []
for truck in new_toll_time['vehicle_no'].unique().tolist():
    if ((new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem'].shape[0] >= 1) and (new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Laxmipuram'].shape[0] >= 1 )):
        new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Laxmipuram'] = new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Laxmipuram'] - new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem']
    else:
        lis_truck.append(truck)

for truck in lis_truck:
    new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Laxmipuram'] = new_toll_time['distance_travelled'][new_toll_time['toll_both'] == 'Laxmipuram'].median()

# %%
lis_truck = []
for truck in new_toll_time['vehicle_no'].unique().tolist():
    if ((new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem'].shape[0] >= 1) and (new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Laxmipuram'].shape[0] >= 1 )):
        new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Laxmipuram'] = new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Laxmipuram'] - new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem']
    else:
        lis_truck.append(truck)

for truck in lis_truck:
    new_toll_time['time_taken'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Laxmipuram'] = new_toll_time['time_taken'][new_toll_time['toll_both'] == 'Laxmipuram'].median()

# %%
#nathavalasa

# %%
lis_truck = []
for truck in new_toll_time['vehicle_no'].unique().tolist():
    if ((new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem'].shape[0] >= 1) and (new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Nathavalasa/ Vizianagaram'].shape[0] >= 1 )):
        new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Nathavalasa/ Vizianagaram'] = new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Nathavalasa/ Vizianagaram'] - new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Chilakapalem']
    else:
        lis_truck.append(truck)

for truck in lis_truck:
    new_toll_time['distance_travelled'][new_toll_time['vehicle_no'] == truck][new_toll_time['toll_both'] == 'Nathavalasa/ Vizianagaram'] = new_toll_time['distance_travelled'][new_toll_time['toll_both'] == 'Nathavalasa/ Vizianagaram'].median()

# %%
 new_toll_time['distance_travelled'][new_toll_time['toll_both'] == 'Laxmipuram']
# Out:
# 713    353.42
# 714    355.02
# 715    355.27
# 716    354.38
# 717    354.27
# 718    355.83
# 719    354.10
# 720    335.42
# 721    358.40
# 722    354.67
# 723    354.01
# 724    353.89
# 725    354.27
# 726    354.37
# 727    354.37
# 728    353.90
# 729    354.48
# 730    349.43
# 731    354.09
# 732    354.89
# 733    354.55
# 734    354.11
# 735    354.41
# 736    354.57
# 737    352.10
# 738    355.13
# 739    317.69
# 740    356.32
# 741    354.98
# 742    354.45
# 743    353.40
# 744    353.87
# 745    355.13
# 746    357.06
# 747    354.04
# 748    356.07
# 749    353.80
# 750    354.61
# 751    354.87
# 752    354.70
# 753    354.25
# 754    354.02
# 755    351.40
# 756    354.71
# 757    354.41
# 758    354.40
# 759    353.59
# Name: distance_travelled, dtype: float64

# %%
new_toll_time
# Out:
#                      toll_both  vehicle_no  delivery_status  \
# 526                  Bellupada  AP05TA9595                1
# 527                  Bellupada  AP05TD6769                1
# 528                  Bellupada  AP05TG1315                1
# 529                  Bellupada   AP05V7856                1
# 530                  Bellupada  AP16TE6019                1
# 531                  Bellupada  AP16TG9159                1
# 532                  Bellupada  AP16TY8489                2
# 533                  Bellupada  AP31TB4579                1
# 534                  Bellupada  AP31TC0679                1
# 535                  Bellupada  AP31TE8359                2
# 536                  Bellupada  AP31TE8739                2
# 537                  Bellupada  AP31TG1179                1
# 538                  Bellupada  AP31TG1179                1
# 539                  Bellupada  AP31TH5279                1
# 540                  Bellupada  AP31TW4459                1
# ...

# %%
new_toll_time.dtypes
# Out:
# toll_both              object
# vehicle_no             object
# loading_out_time       object
# unloading_in_time      object
# delivery_status        object
# distance_travelled    float64
# late_by_hrs           float64
# time_taken            float64
# dtype: object

# %%
new_toll

# %%
for val in new_toll_time
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-0b0b286057cd> in <module>()
#       1 for index,row in new_toll_time.iterrows():
# ----> 2     row['delivery_hrs'] = row['delivery_time'].total_seconds()//3600
#       3
#
# AttributeError: 'str' object has no attribute 'total_seconds'

# %%
# calculate the correlation matrix
corr = new_toll_time.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
plt.show()
