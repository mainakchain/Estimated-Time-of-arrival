# %%
import sqlite3
import numpy as np
import mysql.connector
import pandas as pd
import getpass
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
plotly.tools.set_credentials_file(username='mainakchain', api_key='B9m4DVrYYmsoW3jDSiok')
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
import plotly.figure_factory as ff
from scipy import stats
from sklearn.utils import shuffle
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
daily_histories = pd.read_csv('daily_truck_histories.csv')

# %%
daily_histories.shape
# Out:
# (83554, 25)

# %%
daily_histories.head()
# Out:
#    Unnamed: 0                 date vehicle_no  running_time  stop_time  \
# 0           0  2017-08-09 00:00:00        NaN             0          0
# 1           1  2017-10-02 00:00:00        NaN         61174       8999
# 2           2  2017-10-03 00:00:00        NaN         85416          0
# 3           3  2017-10-04 00:00:00        NaN         85338          1
# 4           4  2017-10-05 00:00:00        NaN         84400          0
#
#    idle_time  distance_travelled  \
# 0          0             1276.60
# 1        924            65681.14
# 2         93           128652.52
# 3        159           134830.93
# 4       1097           141154.11
#
#                                       start_landmark  \
# 0  Road No 2, Bagunhatu, Baridih, Jamshedpur, Jha...
# 1   National Highway 5, Ganjam, Odisha 761026, India
# 2  Aurobindo Pharma Plant, Aurobindo Pharma Inter...
# 3   National Highway 5, Andhra Pradesh 531162, India
# 4  National Highway 5, Belagam, Andhra Pradesh 76...
#
# ...

# %%
for col in daily_histories.columns.tolist():
    print col
# Out:
# Unnamed: 0
# date
# vehicle_no
# running_time
# stop_time
# idle_time
# distance_travelled
# start_landmark
# end_landmark
# start_state
# end_state
# start_date
# end_date
# overspeed_instances
# max_speed
# odometer_km
# n_running
# n_stop_time
# n_idle_time
# n_distance_travelled
# n_odometer_km
# max_timestamp
# count
# createdAt
# updatedAt

# %%
duration_histories = pd.read_csv('duratipn_based_histories.csv')

# %%
duration_histories.shape
# Out:
# (115627, 19)

# %%
for col in duration_histories.columns.tolist():
    print col
# Out:
# Unnamed: 0
# vehicle_no
# distance_travelled
# avg_speed
# start_timestamp
# end_timestamp
# start_landmark
# end_landmark
# old_state
# new_state
# duration
# distance_km
# createdAt
# updatedAt
# end_lat
# end_long
# start_lat
# start_long
# old_distance_km

# %%
toll_time = pd.read_csv('toll_time.csv')

# %%
toll_time.shape
# Out:
# (6425, 18)

# %%
toll_time.head()
# Out:
#    Unnamed: 0    origin    destination  toll_both  vehicle_no  \
# 0           2  Athagarh  Visakhapatnam  Bellupada  OD05AC5222
# 1           9  Athagarh  Visakhapatnam  Bellupada  OD05AC5357
# 2          16  Athagarh  Visakhapatnam  Bellupada  OD05AC7040
# 3          23  Athagarh  Visakhapatnam  Bellupada  OD05AC8545
# 4          30  Athagarh  Visakhapatnam  Bellupada  OD05AC8545
#
#       loading_out_time  odometer_km        ist_timestamp  distance_from_toll  \
# 0  2017-11-22 19:58:42      9254.04  2017-11-24 11:24:30            0.433537
# 1  2017-11-22 19:48:56      6714.74  2017-11-23 15:57:03            0.897817
# 2  2017-11-22 19:49:11      6234.31  2017-11-23 15:57:39            0.368168
# 3  2017-11-25 11:27:55      9569.40  2017-11-25 21:25:43            0.449605
# 4  2017-11-25 11:45:40      9569.40  2017-11-25 21:25:43            0.449605
#
#        loading_in_time           start_date                  eta  \
# ...

# %%
toll = toll_time[toll_time['origin'] == 'Dhenkanal'][toll_time['destination'] == 'Visakhapatnam']
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
con.shape
# Out:
# (489, 4)

# %%
toll['vehicle_no'].nunique()
# Out:
# 44

# %%
consignor_trips_data = pd.read_csv('consignor_data_clean.csv')

# %%
con_data = consignor_trips_data[consignor_trips_data['origin'] == 'Dhenkanal'][consignor_trips_data['destination'] == 'Visakhapatnam'  ]
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
con = con_data[['vehicle_no','start_date','loading_out_time','unloading_in_time']]

# %%
for no in toll.vehicle_no.tolist():
    if con[con]
# Out:
# (489, 4)

# %%
['vehicle_no'].nunique()
# Out:
# 44

# %%
co = con.loc[con['vehicle_no'].isin(toll['vehicle_no'])]

# %%
co['vehicle_no'].nunique()
# Out:
# 29

# %%
tol = toll.loc[toll['vehicle_no'].isin(co['vehicle_no'])]

# %%
tol['vehicle_no'].nunique()
# Out:
# 29

# %%
for col in toll.columns.tolist():
    print col
# Out:
# Unnamed: 0
# origin
# destination
# toll_both
# vehicle_no
# loading_out_time
# odometer_km
# ist_timestamp
# distance_from_toll
# loading_in_time
# start_date
# eta
# unloading_in_time
# slug
# delivery_status
# distance_travelled
# late_by_hrs
# time_taken

# %%
toll.head(10)
# Out:
#      Unnamed: 0     origin    destination  toll_both  vehicle_no  \
# 526         534  Dhenkanal  Visakhapatnam  Bellupada  AP05TA9595
# 527         542  Dhenkanal  Visakhapatnam  Bellupada  AP05TD6769
# 528         550  Dhenkanal  Visakhapatnam  Bellupada  AP05TG1315
# 529         560  Dhenkanal  Visakhapatnam  Bellupada   AP05V7856
# 530         568  Dhenkanal  Visakhapatnam  Bellupada  AP16TE6019
# 531         576  Dhenkanal  Visakhapatnam  Bellupada  AP16TG9159
# 532         584  Dhenkanal  Visakhapatnam  Bellupada  AP16TY8489
# 533         598  Dhenkanal  Visakhapatnam  Bellupada  AP31TB4579
# 534         606  Dhenkanal  Visakhapatnam  Bellupada  AP31TC0679
# 535         613  Dhenkanal  Visakhapatnam  Bellupada  AP31TE8359
#
#         loading_out_time  odometer_km        ist_timestamp  \
# 526  2017-12-01 19:24:17      6020.00  2017-12-02 04:23:40
# 527  2017-11-25 16:09:58     10380.33  2017-11-26 01:56:02
# 528  2017-11-23 19:24:54      2813.92  2017-11-24 04:47:02
# ...

# %%
toll = toll.sort_values('distance_travelled')

# %%
toll.to_csv('toll.csv')

# %%
toll.sort_values('toll_both').to_csv('toll_sorted_both.csv')

# %%
toll.toll_both.value_counts()
# Out:
# Gurapalli                                   48
# Gudipada (Old Gangapada)                    48
# Nathavalasa/ Vizianagaram                   47
# Chilakapalem                                47
# Laxmipuram                                  47
# Madapam                                     46
# Bellupada                                   44
# Main Toll (Gosthani Gate) (Sheela Nagar)    40
# Name: toll_both, dtype: int64

# %%
Xtrain_std = StandardScaler().fit_transform(X_train)
y_std = LabelEncoder().fit_transform(y_train)
# Out:
#      Unnamed: 0     origin    destination  \
# 653         798  Dhenkanal  Visakhapatnam
# 628         604  Dhenkanal  Visakhapatnam
# 627         596  Dhenkanal  Visakhapatnam
# 626         590  Dhenkanal  Visakhapatnam
# 625         582  Dhenkanal  Visakhapatnam
# 623         566  Dhenkanal  Visakhapatnam
# 622         558  Dhenkanal  Visakhapatnam
# 621         556  Dhenkanal  Visakhapatnam
# 620         548  Dhenkanal  Visakhapatnam
# 619         540  Dhenkanal  Visakhapatnam
# 618         532  Dhenkanal  Visakhapatnam
# 629         611  Dhenkanal  Visakhapatnam
# 617         526  Dhenkanal  Visakhapatnam
# 655         814  Dhenkanal  Visakhapatnam
# 656         822  Dhenkanal  Visakhapatnam
# 657         830  Dhenkanal  Visakhapatnam
# 658         838  Dhenkanal  Visakhapatnam
# 659         846  Dhenkanal  Visakhapatnam
# 660         854  Dhenkanal  Visakhapatnam
# 661         862  Dhenkanal  Visakhapatnam
# 662         870  Dhenkanal  Visakhapatnam
# ...

# %%
toll['toll_both'] = toll['toll_both'].astype('category')

# %%
toll.drop[['origin','destination']]
# Out:
#      Unnamed: 0     origin    destination                  toll_both  \
# 526         534  Dhenkanal  Visakhapatnam                  Bellupada
# 527         542  Dhenkanal  Visakhapatnam                  Bellupada
# 528         550  Dhenkanal  Visakhapatnam                  Bellupada
# 529         560  Dhenkanal  Visakhapatnam                  Bellupada
# 530         568  Dhenkanal  Visakhapatnam                  Bellupada
# 531         576  Dhenkanal  Visakhapatnam                  Bellupada
# 532         584  Dhenkanal  Visakhapatnam                  Bellupada
# 533         598  Dhenkanal  Visakhapatnam                  Bellupada
# 534         606  Dhenkanal  Visakhapatnam                  Bellupada
# 535         613  Dhenkanal  Visakhapatnam                  Bellupada
# 536         621  Dhenkanal  Visakhapatnam                  Bellupada
# 537         631  Dhenkanal  Visakhapatnam                  Bellupada
# 538         632  Dhenkanal  Visakhapatnam                  Bellupada
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.3, random_state=42)
