# %%
import sqlite3
import numpy as np
import mysql.connector
import pandas as pd
import getpass
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
plotly.tools.set_credentials_file(username='mainakchain', api_key='B9m4DVrYYmsoW3jDSiok')
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
import plotly.figure_factory as ff
from scipy import stats
from sklearn.utils import shuffle
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Open the file
f = open('gps_development.csv', 'rw')
# Create a connection and get a cursor
password = getpass.getpass('Enter your mysql password: ')
cnx = mysql.connector.connect(user='root', password=password, database='gps_development')
cursor = cnx.cursor()
# Out:
# Enter your mysql password: ········

# %%
pd.read_sql('show tables;', cnx )
# Out:
#    Tables_in_gps_development
# 0              SequelizeMeta
# 1                     alerts
# 2            daily_histories
# 3     daily_populator_logger
# 4           device_histories
# 5                    devices
# 6   duration_based_histories
# 7          look_up_histories
# 8         look_up_histories2
# 9          new_poi_histories
# 10             poi_histories
# 11                      pois
# 12             route_mapping
# 13            route_mappings
# 14         schema_migrations
# 15                 trip_pois
# 16               trip_trucks
# 17                     trips
# 18           truck_histories
# 19                    trucks
# 20                     users
# 21              vehicle_pois

# %%
daily_truck_histories_data = pd.read_sql('select * from daily_histories;', cnx )

# %%
duration_based_histories_data = pd.read_sql('select * from duration_based_histories;', cnx)

# %%
trucks_data = pd.read_sql('select * from trucks;', cnx)

# %%
trucks_data.shape
# Out:
# (8766, 32)

# %%
duration_based_histories_data.shape
# Out:
# (115627, 18)

# %%
daily_truck_histories_data.shape
# Out:
# (83554, 24)

# %%
duration_based_histories_data.describe()
# Out:
#        distance_travelled      avg_speed       duration   distance_km  \
# count       115627.000000  115627.000000  115627.000000  1.156270e+05
# mean          1909.221586       9.409833    2782.315186  5.317813e+04
# std          13238.946399      80.823778    8850.900058  5.201612e+05
# min              0.000000       0.000000       0.000000  0.000000e+00
# 25%              0.100000       0.000000      60.000000  5.004625e+03
# 50%              0.290000       3.700000     300.000000  8.035960e+03
# 75%              3.600000      14.820000    1500.000000  1.586424e+04
# max         119528.690000   22047.950000   86389.000000  2.052247e+07
#
#              end_lat       end_long      start_lat     start_long  \
# count  115627.000000  115627.000000  115627.000000  115627.000000
# mean       22.997684      81.620404      23.002954      81.633601
# std         4.017088       4.256100       4.008039       4.255567
# min         9.926461      69.647102       9.926461      69.647102
# 25%        20.723401      77.305683      20.757785      77.306190
# 50%        22.773413      82.552895      22.773527      82.584343
# 75%        26.472635      85.667862      26.456936      85.706017
# max        31.875216      88.928192      31.875216      88.911522
#
#        old_distance_km
# count     1.156270e+05
# mean      5.319093e+04
# std       5.201581e+05
# min       0.000000e+00
# 25%       4.999725e+03
# 50%       8.031400e+03
# 75%       1.586708e+04
# max       2.052247e+07

# %%
duration_based_histories_data.to_csv('duratipn_based_histories.csv', encoding='utf-8')

# %%
daily_truck_histories_data.to_csv('daily_truck_histories.csv', encoding='utf-8')

# %%
trucks_data.to_csv('trucks.csv', encoding='utf-8')

# %%
vehicle_sorted_duration_data = duration_based_histories_data.sort_values(['start_timestamp'], ascending=True)

# %%
vehicle_sorted_duration_data
# Out:
#              vehicle_no  distance_travelled  avg_speed     start_timestamp  \
# 1277    864287032539742                0.00       9.26 2017-10-03 13:55:31
# 1278    864287032539742                0.02       0.00 2017-10-03 13:58:31
# 1279    864287032539742                0.00       7.41 2017-10-03 13:59:30
# 1280    864287032539742                0.02       0.00 2017-10-03 14:18:28
# 1281    864287032539742                0.99      20.37 2017-10-03 14:19:27
# 2620    864495030652447                0.00       0.00 2017-10-03 20:54:40
# 1282    864287032539742                6.22       0.00 2017-10-03 21:52:30
# 1283    864287032539742                0.00       0.00 2017-10-03 22:09:31
# 1284    864287032539742                0.09       0.17 2017-10-04 13:31:29
# 701     864287032479717                0.65       0.19 2017-10-04 18:28:18
# 1566    864495030627076            17779.52   15831.38 2017-10-04 19:16:33
# 3177              90805                0.01       0.01 2017-10-04 21:33:30
# 1134    864287032501437                3.24       0.00 2017-10-05 16:26:37
# 1135    864287032501437               45.83      42.60 2017-10-05 16:33:27
# 1136    864287032501437               28.77      44.45 2017-10-05 18:18:13
# 1137    864287032501437                0.00       0.00 2017-10-06 04:14:28
# 4404         AP07TB1989                0.17      14.82 2017-10-07 00:00:18
# 4405         AP07TB1989                0.34       1.85 2017-10-07 00:55:22
# 4406         AP07TB1989                0.01      16.67 2017-10-07 01:20:39
# 4407         AP07TB1989                0.08       0.00 2017-10-07 01:33:17
# 4408         AP07TB1989                0.07      11.11 2017-10-07 01:44:07
# 4409         AP07TB1989                0.22       0.00 2017-10-07 01:44:57
# 4410         AP07TB1989                0.11       5.56 2017-10-07 01:45:56
# 1138    864287032501437              312.26       0.00 2017-10-07 02:08:29
# 4411         AP07TB1989                0.10       0.00 2017-10-07 03:05:23
# 4412         AP07TB1989                1.13       9.26 2017-10-07 03:06:22
# 4413         AP07TB1989                0.18       3.70 2017-10-07 04:46:59
# 4414         AP07TB1989                0.10       0.12 2017-10-07 04:47:49
# 1492    864287032563429                0.00       0.00 2017-10-07 05:12:33
# 1139    864287032501437                0.00       0.00 2017-10-07 14:53:15
# ...                 ...                 ...        ...                 ...
# 12999        BR01GC3627                0.02       0.30 2017-11-29 23:55:56
# 109313       TN67AS4843                0.49       5.56 2017-11-29 23:56:13
# 56346         KA01B6427                0.00       0.00 2017-11-29 23:56:31
# 16316        CG04JB2584                0.32       0.00 2017-11-29 23:56:39
# 45258        HR55AA9555                0.09       9.26 2017-11-29 23:56:47
# 103317       RJ14GC0351                0.14      11.11 2017-11-29 23:56:50
# 24681         GJ20U4455                0.08       0.00 2017-11-29 23:56:51
# 111401        WB11C6385                0.16      11.11 2017-11-29 23:56:53
# 8583         AP27TT2439                0.14       2.80 2017-11-29 23:56:59
# 45259        HR55AA9555                0.22      12.96 2017-11-29 23:57:17
# 107270       TN28AJ6775                0.00       0.00 2017-11-29 23:57:22
# 56347         KA01B6427                0.01       5.56 2017-11-29 23:57:31
# 13292        BR01GF2042                0.61      16.67 2017-11-29 23:57:35
# 66801         NL01G5344                0.09      16.67 2017-11-29 23:57:44
# 101232        PB12Y8871                0.00       0.00 2017-11-29 23:57:45
# 103318       RJ14GC0351                0.04       1.85 2017-11-29 23:57:50
# 24682         GJ20U4455                0.00       0.00 2017-11-29 23:57:51
# 111402        WB11C6385                0.01       0.00 2017-11-29 23:57:53
# 16673        CG04JB7687                0.16       9.60 2017-11-29 23:58:13
# 56348         KA01B6427                0.19      11.11 2017-11-29 23:58:31
# 86628         OD04K2272                0.00       0.00 2017-11-29 23:58:40
# 66802         NL01G5344                0.59      14.82 2017-11-29 23:58:44
# 64948        NL01AA1122                0.50      31.48 2017-11-29 23:58:49
# 103319       RJ14GC0351                0.02       1.20 2017-11-29 23:58:50
# 111403        WB11C6385                0.01       0.60 2017-11-29 23:58:53
# 45260        HR55AA9555                0.09       7.41 2017-11-29 23:59:24
# 13598         BR26E5784                0.00       0.00 2017-11-29 23:59:33
# 16317        CG04JB2584                0.00       0.00 2017-11-29 23:59:48
# 45261        HR55AA9555                0.00       0.00 2017-11-29 23:59:54
# 22468        GJ03BV8878                0.00       0.00 2017-11-30 00:00:00
#
#              end_timestamp                                     start_landmark  \
# 1277   2017-10-03 13:58:31               Jamshedpur, Jharkhand, India, 832110
# 1278   2017-10-03 13:59:30               Jamshedpur, Jharkhand, India, 832110
# 1279   2017-10-03 14:18:28               Jamshedpur, Jharkhand, India, 832110
# 1280   2017-10-03 14:19:27               Jamshedpur, Jharkhand, India, 832110
# 1281   2017-10-03 21:52:30               Jamshedpur, Jharkhand, India, 832110
# 2620   2017-10-03 20:54:40                       NILKAMAL HOTEL-BARIPADA - OR
# 1282   2017-10-03 22:09:31  New Purulia Road, Jamshedpur, Jharkhand, India...
# 1283   2017-10-03 22:11:31               Jamshedpur, Jharkhand, India, 831009
# 1284   2017-10-04 14:03:27               Jamshedpur, Jharkhand, India, 831009
# 701    2017-10-04 21:55:17   Huskur Road, Bengaluru, Karnataka, India, 562162
# 1566   2017-10-04 20:23:56  Namdih Rd  Kailash Nagar  Namda Basti  Jamshed...
# 3177   2017-10-04 22:34:22  Namdih Rd  Kailash Nagar  Namda Basti  Jamshed...
# 1134   2017-10-05 16:33:27                                  BHUBANESHWAR - OR
# 1135   2017-10-05 18:18:13  NH16  Patrapada  Bhubaneswar  Odisha 752054  I...
# 1136   2017-10-05 20:11:52                          RLY CROSING BALUGAON - OR
# 1137   2017-10-06 12:07:51  Natavalasa Toll Gate  NH 5  Natavalasa  Andhra...
# 4404   2017-10-07 00:55:22  NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...
# 4405   2017-10-07 01:20:39               Jamshedpur, Jharkhand, India, 832110
# 4406   2017-10-07 01:33:17  NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...
# 4407   2017-10-07 01:44:07  NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...
# 4408   2017-10-07 01:44:57  NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...
# 4409   2017-10-07 01:45:56                         PARDIH KALI MANDIR_JH - JH
# 4410   2017-10-07 03:05:23                         PARDIH KALI MANDIR_JH - JH
# 1138   2017-10-07 14:53:15                                        KOVVUR - AP
# 4411   2017-10-07 03:06:22  NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...
# 4412   2017-10-07 04:46:59  NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...
# 4413   2017-10-07 04:47:49  NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...
# 4414   2017-10-07 05:38:00  NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...
# 1492   2017-10-07 05:12:33   Bangalore Road, Hosur, Tamil Nadu, India, 635126
# 1139   2017-10-07 14:53:15  Guntur-Chennai Highway-Kanupuru Bit - I-Nellor...
# ...                    ...                                                ...
# 12999  2017-11-29 23:59:56               Jamshedpur, Jharkhand, India, 831007
# 109313 2017-11-29 23:59:13               Jamshedpur, Jharkhand, India, 831007
# 56346  2017-11-29 23:57:31  Dimna Road, Jamshedpur, Purbi Singhbhum, Jhark...
# 16316  2017-11-29 23:59:48  29  Dimna Main Rd  Gandhi Ghat  Mango  Jamshed...
# 45258  2017-11-29 23:57:17  Grand Trunk Rd  Swami Shraddhanand Park  Bhals...
# 103317 2017-11-29 23:57:50  Agra Jaipur Bikaner Road, Achnera, Agra, Uttar...
# 24681  2017-11-29 23:57:51  NH-25, Jhansi Sub-District, Uttar Pradesh, Ind...
# 111401 2017-11-29 23:57:53  rangangoan fhata, Waluj MIDC, Ranjangoan, Aura...
# 8583   2017-11-29 23:59:59                NH16, Tangi, Cuttack, Odisha, India
# 45259  2017-11-29 23:59:24                             LAXMI AGRO ALIPUR - DL
# 107270 2017-11-29 23:57:22  Jamshedpur-Chaibasa Road, Chaibasa, Jharkhand,...
# 56347  2017-11-29 23:58:31  Dimna Road, Jamshedpur, Purbi Singhbhum, Jhark...
# 13292  2017-11-29 23:59:35  Subarnrekha Link Road, Jamshedpur, Purbi Singh...
# 66801  2017-11-29 23:58:44          NH-75, Chaibasa, Jharkhand, India, 833202
# 101232 2017-11-29 23:59:45  Main Road Rampur, Mariahu, Uttar Pradesh, Indi...
# 103318 2017-11-29 23:58:50  Agra-Bikaner Rd  Korai  Uttar Pradesh 283110  ...
# 24682  2017-11-29 23:59:51  Shivpuri -Jhansi Rd  Raksa  Madhya Pradesh 284...
# 111402 2017-11-29 23:58:53  rangangoan fhata, Waluj MIDC, Ranjangoan, Aura...
# 16673  2017-11-29 23:59:13  NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...
# 56348  2017-11-29 23:59:31  Dimna Road, Jamshedpur, Purbi Singhbhum, Jhark...
# 86628  2017-11-29 23:59:40  National Highway 60, Beliara, Bankura, West Be...
# 66802  2017-11-29 23:59:44          NH-75, Chaibasa, Jharkhand, India, 833202
# 64948  2017-11-29 23:59:49               Jamshedpur, Jharkhand, India, 831001
# 103319 2017-11-29 23:59:50  Agra-Bikaner Rd  Korai  Uttar Pradesh 283110  ...
# 111403 2017-11-29 23:59:53  rangangoan fhata, Waluj MIDC, Ranjangoan, Aura...
# 45260  2017-11-29 23:59:54             Grand Trunk Road, Delhi, 110042, India
# 13598  2017-11-29 23:59:33  NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...
# 16317  2017-11-29 23:59:48  Dimna Road, Jamshedpur, Purbi Singhbhum, Jhark...
# 45261  2017-11-29 23:59:54             Grand Trunk Road, Delhi, 110042, India
# 22468  2017-11-30 00:00:00          SH-4, Shirpur, Maharashtra, India, 425405
#
#                                              end_landmark old_state new_state  \
# 1277                 Jamshedpur, Jharkhand, India, 832110   stopped    moving
# 1278                 Jamshedpur, Jharkhand, India, 832110    moving   stopped
# 1279                 Jamshedpur, Jharkhand, India, 832110   stopped    moving
# 1280                 Jamshedpur, Jharkhand, India, 832110    moving   stopped
# 1281    New Purulia Road, Jamshedpur, Jharkhand, India...   stopped    moving
# 2620                         NILKAMAL HOTEL-BARIPADA - OR   stopped   stopped
# 1282                 Jamshedpur, Jharkhand, India, 831009    moving   stopped
# 1283                 Jamshedpur, Jharkhand, India, 831009   stopped   stopped
# 1284                 Jamshedpur, Jharkhand, India, 831009   stopped   stopped
# 701      Huskur Road, Bengaluru, Karnataka, India, 562162   stopped   stopped
# 1566    Namdih Rd  Kailash Nagar  Namda Basti  Jamshed...   stopped   stopped
# 3177    Namdih Rd  Kailash Nagar  Namda Basti  Jamshed...   stopped   stopped
# 1134    NH16  Patrapada  Bhubaneswar  Odisha 752054  I...    moving   stopped
# 1135                            RLY CROSING BALUGAON - OR   stopped    moving
# 1136             NH 5  Nirmalajhara  Odisha 761029  India    moving    moving
# 1137    Natavalasa Toll Gate  NH 5  Natavalasa  Andhra...   stopped   stopped
# 4404                 Jamshedpur, Jharkhand, India, 832110   stopped    moving
# 4405    NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...    moving   stopped
# 4406    NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...   stopped    moving
# 4407    NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...    moving   stopped
# 4408                           PARDIH KALI MANDIR_JH - JH   stopped    moving
# 4409                           PARDIH KALI MANDIR_JH - JH    moving   stopped
# 4410    NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...   stopped    moving
# 1138    Guntur-Chennai Highway-Kanupuru Bit - I-Nellor...    moving   stopped
# 4411    NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...    moving   stopped
# 4412    NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...   stopped    moving
# 4413    NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...    moving   stopped
# 4414    NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...   stopped   stopped
# 1492     Bangalore Road, Hosur, Tamil Nadu, India, 635126   stopped   stopped
# 1139    Guntur-Chennai Highway-Kanupuru Bit - I-Nellor...   stopped   stopped
# ...                                                   ...       ...       ...
# 12999                Jamshedpur, Jharkhand, India, 831007   stopped   stopped
# 109313  Rd Number 6  Bajrangi Bagan  Lakshimi Nagar  B...    moving    moving
# 56346   Dimna Road, Jamshedpur, Purbi Singhbhum, Jhark...    moving   stopped
# 16316   Dimna Road, Jamshedpur, Purbi Singhbhum, Jhark...    moving   stopped
# 45258                              LAXMI AGRO ALIPUR - DL    moving      idle
# 103317  Agra-Bikaner Rd  Korai  Uttar Pradesh 283110  ...   stopped    moving
# 24681   Shivpuri -Jhansi Rd  Raksa  Madhya Pradesh 284...    moving   stopped
# 111401  rangangoan fhata, Waluj MIDC, Ranjangoan, Aura...   stopped    moving
# 8583                                 TOLL TAX PAMULI - OR   stopped   stopped
# 45259              Grand Trunk Road, Delhi, 110042, India      idle    moving
# 107270  Jamshedpur-Chaibasa Road, Chaibasa, Jharkhand,...   stopped   stopped
# 56347   Dimna Road, Jamshedpur, Purbi Singhbhum, Jhark...   stopped    moving
# 13292                                   MANGO BRIDGE - JH    moving    moving
# 66801           NH-75, Chaibasa, Jharkhand, India, 833202   stopped    moving
# 101232  Main Road Rampur, Mariahu, Uttar Pradesh, Indi...   stopped   stopped
# 103318  Agra-Bikaner Rd  Korai  Uttar Pradesh 283110  ...    moving   stopped
# 24682   Shivpuri -Jhansi Rd  Raksa  Madhya Pradesh 284...   stopped   stopped
# 111402  rangangoan fhata, Waluj MIDC, Ranjangoan, Aura...    moving   stopped
# 16673   NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...   stopped   stopped
# 56348   Hume Pipe Rd  Gautam Vihar  Jamshedpur  Jharkh...    moving    moving
# 86628   National Highway 60, Beliara, Bankura, West Be...   stopped   stopped
# 66802           NH-75, Chaibasa, Jharkhand, India, 833202    moving    moving
# 64948                                   MANGO BRIDGE - JH    moving    moving
# 103319  Agra-Bikaner Rd  Korai  Uttar Pradesh 283110  ...   stopped   stopped
# 111403  rangangoan fhata, Waluj MIDC, Ranjangoan, Aura...   stopped   stopped
# 45260              Grand Trunk Road, Delhi, 110042, India    moving      idle
# 13598   NH33, Jamshedpur, Purbi Singhbhum, Jharkhand, ...   stopped   stopped
# 16317   Dimna Road, Jamshedpur, Purbi Singhbhum, Jhark...   stopped   stopped
# 45261              Grand Trunk Road, Delhi, 110042, India      idle      idle
# 22468           SH-4, Shirpur, Maharashtra, India, 425405   stopped   stopped
#
#         duration  distance_km           createdAt           updatedAt  \
# 1277         180      4197.83 2017-11-27 16:12:41 2017-11-27 16:12:41
# 1278          59      4197.85 2017-11-27 16:12:41 2017-11-27 16:12:41
# 1279        1138      4197.83 2017-11-27 16:12:41 2017-11-27 16:12:41
# 1280          59      4197.85 2017-11-27 16:12:41 2017-11-27 16:12:41
# 1281       27183      4198.84 2017-11-27 16:12:41 2017-11-27 16:12:41
# 2620           0      1403.11 2017-11-27 16:11:36 2017-11-27 16:11:36
# 1282        1021      4205.06 2017-11-27 16:12:41 2017-11-27 16:12:41
# 1283         120      4205.06 2017-11-27 16:12:41 2017-11-27 16:12:41
# 1284        1918      4205.12 2017-11-27 16:12:41 2017-11-27 16:12:41
# 701        12419      2544.28 2017-11-27 16:12:32 2017-11-27 16:12:32
# 1566        4043     18890.74 2017-11-27 16:12:47 2017-11-27 16:12:47
# 3177        3652         0.01 2017-11-27 16:12:54 2017-11-27 16:12:54
# 1134         410      2420.19 2017-11-27 16:12:38 2017-11-27 16:12:38
# 1135        6286      2466.02 2017-11-27 16:12:38 2017-11-27 16:12:38
# 1136        6819      2494.79 2017-11-27 16:12:38 2017-11-27 16:12:38
# 1137       28403      2689.36 2017-11-27 16:12:38 2017-11-27 16:12:38
# 4404        3304      1719.82 2017-11-27 16:12:58 2017-11-27 16:12:58
# 4405        1517      1720.16 2017-11-27 16:12:58 2017-11-27 16:12:58
# 4406         758      1720.17 2017-11-27 16:12:58 2017-11-27 16:12:58
# 4407         650      1720.25 2017-11-27 16:12:58 2017-11-27 16:12:58
# 4408          50      1720.32 2017-11-27 16:12:58 2017-11-27 16:12:58
# 4409          59      1720.54 2017-11-27 16:12:58 2017-11-27 16:12:58
# 4410        4767      1720.65 2017-11-27 16:12:58 2017-11-27 16:12:58
# 1138       45886      3186.81 2017-11-27 16:12:38 2017-11-27 16:12:38
# 4411          59      1720.75 2017-11-27 16:12:58 2017-11-27 16:12:58
# 4412        6037      1721.88 2017-11-27 16:12:58 2017-11-27 16:12:58
# 4413          50      1722.06 2017-11-27 16:12:58 2017-11-27 16:12:58
# 4414        3011      1722.16 2017-11-27 16:12:58 2017-11-27 16:12:58
# 1492           0      6102.78 2017-11-27 16:11:16 2017-11-27 16:11:16
# 1139           0      3186.81 2017-11-27 16:12:38 2017-11-27 16:12:38
# ...          ...          ...                 ...                 ...
# 12999        240      7614.04 2017-12-01 23:55:09 2017-12-01 23:55:09
# 109313       180      6944.27 2017-12-01 23:55:52 2017-12-01 23:55:52
# 56346         60      7395.90 2017-12-01 23:55:31 2017-12-01 23:55:31
# 16316        189      6142.89 2017-12-01 23:55:14 2017-12-01 23:55:14
# 45258         30     41681.75 2017-12-01 23:55:25 2017-12-01 23:55:25
# 103317        60      6823.33 2017-12-01 23:55:49 2017-12-01 23:55:49
# 24681         60      4935.71 2017-12-01 23:55:23 2017-12-01 23:55:23
# 111401        60      6508.19 2017-12-01 23:55:53 2017-12-01 23:55:53
# 8583         180      4910.79 2017-12-01 23:55:07 2017-12-01 23:55:07
# 45259        127     41681.97 2017-12-01 23:55:25 2017-12-01 23:55:25
# 107270         0      1323.59 2017-12-01 23:55:51 2017-12-01 23:55:51
# 56347         60      7395.91 2017-12-01 23:55:31 2017-12-01 23:55:31
# 13292        120      1276.23 2017-12-01 23:55:09 2017-12-01 23:55:09
# 66801         60       592.50 2017-12-01 23:55:35 2017-12-01 23:55:35
# 101232       120      6987.36 2017-12-01 23:55:48 2017-12-01 23:55:48
# 103318        60      6823.37 2017-12-01 23:55:49 2017-12-01 23:55:49
# 24682        120      4935.71 2017-12-01 23:55:23 2017-12-01 23:55:23
# 111402        60      6508.20 2017-12-01 23:55:53 2017-12-01 23:55:53
# 16673         60      5444.99 2017-12-01 23:55:16 2017-12-01 23:55:16
# 56348         60      7396.10 2017-12-01 23:55:31 2017-12-01 23:55:31
# 86628         60      2388.68 2017-12-01 23:55:40 2017-12-01 23:55:40
# 66802         60       593.09 2017-12-01 23:55:35 2017-12-01 23:55:35
# 64948         60      7759.67 2017-12-01 23:55:34 2017-12-01 23:55:34
# 103319        60      6823.39 2017-12-01 23:55:49 2017-12-01 23:55:49
# 111403        60      6508.21 2017-12-01 23:55:53 2017-12-01 23:55:53
# 45260         30     41682.06 2017-12-01 23:55:25 2017-12-01 23:55:25
# 13598          0      7288.00 2017-12-01 23:55:10 2017-12-01 23:55:10
# 16317          0      6142.89 2017-12-01 23:55:14 2017-12-01 23:55:14
# 45261          0     41682.06 2017-12-01 23:55:25 2017-12-01 23:55:25
# 22468          0      7383.44 2017-12-01 23:55:20 2017-12-01 23:55:20
#
#           end_lat   end_long  start_lat  start_long  old_distance_km
# 1277    22.830940  86.209389  22.830879   86.209343          4197.83
# 1278    22.830879  86.209389  22.830940   86.209389          4197.83
# 1279    22.831039  86.209290  22.830879   86.209389          4197.85
# 1280    22.831030  86.209320  22.831039   86.209290          4197.83
# 1281    22.831110  86.211372  22.831030   86.209320          4197.85
# 2620    22.078413  86.642563  22.078413   86.642563          1403.11
# 1282    22.813730  86.234734  22.831110   86.211372          4198.84
# 1283    22.813700  86.234703  22.813730   86.234734          4205.06
# 1284    22.813700  86.233902  22.813400   86.234520          4205.03
# 701     13.082798  77.449417  13.082762   77.449211          2543.63
# 1566    22.774048  86.216980  22.774048   86.216980          1111.22
# 3177    22.773792  86.216751  22.773869   86.216667             0.00
# 1134    20.229786  85.737091  20.244392   85.773712          2416.95
# 1135    19.863575  85.323303  20.229786   85.737091          2420.19
# 1136    19.600691  85.115578  19.863575   85.323303          2466.02
# 1137    18.054119  83.518654  18.054123   83.518600          2689.36
# 4404    22.848694  86.206490  22.849764   86.207848          1719.65
# 4405    22.849829  86.207878  22.848694   86.206490          1719.82
# 4406    22.849731  86.207664  22.849829   86.207878          1720.16
# 4407    22.849520  86.207878  22.849731   86.207664          1720.17
# 4408    22.849201  86.208542  22.849520   86.207878          1720.25
# 4409    22.849089  86.208626  22.849201   86.208542          1720.32
# 4410    22.850130  86.208221  22.849089   86.208626          1720.54
# 1138    14.312172  79.916290  17.019970   81.662910          2874.55
# 4411    22.849588  86.207848  22.850130   86.208221          1720.65
# 4412    22.849319  86.207878  22.849588   86.207848          1720.75
# 4413    22.849318  86.207794  22.849319   86.207878          1721.88
# 4414    22.849661  86.207977  22.849318   86.207794          1722.06
# 1492    12.764900  77.792862  12.764900   77.792862          6102.78
# 1139    14.312172  79.916290  14.312172   79.916290          3186.81
# ...           ...        ...        ...         ...              ...
# 12999   22.773046  86.217384  22.773205   86.217300          7614.02
# 109313  22.771416  86.219513  22.772270   86.217987          6943.78
# 56346   22.810841  86.218346  22.810823   86.218346          7395.90
# 16316   22.815821  86.211250  22.814730   86.214012          6142.57
# 45258   28.745569  77.152046  28.746302   77.151810         41681.66
# 103317  27.114456  77.714630  27.114826   77.716019          6823.19
# 24681   25.462618  78.447693  25.462650   78.448402          4935.63
# 111401  19.850712  75.204338  19.851810   75.205215          6508.03
# 8583    20.542213  85.967415  20.542562   85.968391          4910.65
# 45259   28.743454  77.152863  28.745569   77.152046         41681.75
# 107270  22.551428  85.830666  22.551428   85.830666          1323.59
# 56347   22.810953  86.218277  22.810841   86.218346          7395.90
# 13292   22.820585  86.212875  22.815968   86.210220          1275.62
# 66801   22.522421  85.808395  22.523132   85.808220           592.41
# 101232  25.461185  82.569725  25.461189   82.569725          6987.36
# 103318  27.114307  77.714279  27.114456   77.714630          6823.33
# 24682   25.462627  78.447693  25.462618   78.447693          4935.71
# 111402  19.850601  75.204254  19.850712   75.204338          6508.19
# 16673   22.847298  86.211197  22.846386   86.212372          5444.83
# 56348   22.812122  86.217056  22.810953   86.218277          7395.91
# 86628   23.196911  87.124870  23.196911   87.124870          2388.68
# 66802   22.517179  85.807602  22.522421   85.808395           592.50
# 64948   22.817606  86.195915  22.816320   86.200523          7759.17
# 103319  27.114233  77.714188  27.114307   77.714279          6823.37
# 111403  19.850569  75.204239  19.850601   75.204254          6508.20
# 45260   28.742662  77.153107  28.743454   77.152863         41681.97
# 13598   22.845980  86.212875  22.845980   86.212875          7288.00
# 16317   22.815821  86.211250  22.815821   86.211250          6142.89
# 45261   28.742662  77.153107  28.742662   77.153107         41682.06
# 22468   21.372770  74.854088  21.372770   74.854088          7383.44
#
# [115627 rows x 18 columns]

# %%
f = open('dipper_development.csv', 'rw')
# Create a connection and get a cursor
password = getpass.getpass('Enter your mysql password: ')
cnx = mysql.connector.connect(user='root', password=password, database='dipper_development')
cursor = cnx.cursor()
# Out:
# Enter your mysql password: ········

# %%
pd.read_sql('show tables;', cnx)
# Out:
#        Tables_in_dipper_development
# 0                          accounts
# 1                     address_types
# 2                         addresses
# 3                       alert_types
# 4                     bank_accounts
# 5                          bookings
# 6                            cities
# 7                          comments
# 8                          consents
# 9                        consignees
# 10                 consigner_cities
# 11                  consigner_trips
# 12                       consigners
# 13                          coupons
# 14                          devices
# 15                          drivers
# 16                   external_trips
# 17                      job_loggers
# 18                    load_subtypes
# 19              loading_supervisors
# 20                            loads
# 21         location_consent_loggers
# 22  mailboxer_conversation_opt_outs
# 23          mailboxer_conversations
# 24          mailboxer_notifications
# 25               mailboxer_receipts
# 26                      near_cities
# 27                      newsletters
# 28              non_consigner_trips
# 29                    payment_infos
# 30               petro_card_masters
# 31                      petro_cards
# 32                      phone_types
# 33                           phones
# 34                         pincodes
# 35                   referral_bonus
# 36                 referral_bonuses
# 37                referral_programs
# 38                   referral_types
# 39                        referrals
# 40                            roles
# 41                       rpush_apps
# 42                   rpush_feedback
# 43              rpush_notifications
# 44                schema_migrations
# 45                  share_locations
# 46                         shippers
# 47             temp_consigner_trips
# 48           trucker_request_trucks
# 49                 trucker_requests
# 50                         truckers
# 51                           trucks
# 52                 user_alert_types
# 53                       user_roles
# 54                            users
# 55                users_newsletters

# %%
consignor_data = pd.read_sql('select * from consigner_trips',cnx)

# %%
consignor_data.head()
# Out:
#    id  trucker_id  truck_id  shipper_id  consigner_id consignee_id source  \
# 0   1           2       107         NaN           NaN         None   None
# 1   2           2        82         NaN           NaN         None   None
# 2   3           2        66         NaN           NaN         None   None
# 3   4           2        28         NaN           NaN         None   None
# 4   5           2        84         NaN           NaN         None   None
#
#                                          data_string  invoice_no  \
# 0  {"card_no":"AA012027","vehicle_no":"NL01N0967"...  2418092375
# 1  {"card_no":"2ff1a4c7","vehicle_no":"NL01N0978"...  5090026139
# 2  {"card_no":"d3babd73","vehicle_no":"NL01N0959"...  5090026132
# 3  {"card_no":"D3A29813","vehicle_no":"NL01G3100"...  2442022294
# 4  {"card_no":"2FE8C937","vehicle_no":"NL01N1072"...  5000100115
#
#   lorry_receipt_no          ...           consigner_long loading_in_time  \
# 0             None          ...                      NaN             NaT
# 1             None          ...                      NaN             NaT
# 2             None          ...                      NaN             NaT
# 3             None          ...                      NaN             NaT
# 4             None          ...                      NaN             NaT
#
#   loading_out_time unloading_in_time unloading_out_time  IMEI loading_poi_id  \
# 0              NaT               NaT                NaT  None            NaN
# 1              NaT               NaT                NaT  None            NaN
# 2              NaT               NaT                NaT  None            NaN
# 3              NaT               NaT                NaT  None            NaN
# 4              NaT               NaT                NaT  None            NaN
#
#   unloading_poi_id unloading_poi_history_id loading_poi_history_id
# 0              NaN                     None                   None
# 1              NaN                     None                   None
# 2              NaN                     None                   None
# 3              NaN                     None                   None
# 4              NaN                     None                   None
#
# [5 rows x 48 columns]

# %%
consignor_data.isnull().sum()/consignor_data.shape[0] * 100
# Out:
# id                            0.000000
# trucker_id                    0.000000
# truck_id                      0.000000
# shipper_id                   53.035672
# consigner_id                 49.274746
# consignee_id                100.000000
# source                      100.000000
# data_string                   0.004725
# invoice_no                    1.960784
# lorry_receipt_no            100.000000
# consigner_name                0.000000
# consignee_name                0.000000
# transporter                   0.000000
# eta                           0.000000
# origin                        4.431845
# destination                   0.000000
# loading_area                100.000000
# start_date                   32.407276
# end_date                    100.000000
# closed_by                    34.486180
# closed_date                  39.347980
# is_active                     0.000000
# created_at                    0.000000
# updated_at                    0.000000
# slug                          0.000000
# card_no                      42.518309
# vehicle_entry_time            9.558233
# vehicle_exit_time             9.945665
# vehicle_no                    0.000000
# status                       32.884479
# state                         0.675644
# consigner_pincode_id        100.000000
# consignee_pincode_id         37.850224
# consignee_lat                27.328136
# consignee_long               27.328136
# closure_reason               34.599575
# consigner_code               41.044177
# consigner_lat                49.723600
# consigner_long               49.723600
# loading_in_time              65.079140
# loading_out_time             69.619655
# unloading_in_time            61.606426
# unloading_out_time           66.369005
# IMEI                        100.000000
# loading_poi_id               86.992677
# unloading_poi_id             88.995984
# unloading_poi_history_id    100.000000
# loading_poi_history_id      100.000000
# dtype: float64

# %%
consignor_data_clean = consignor_data[pd.notnull(consignor_data['loading_out_time'])]

# %%
consignor_data_clean = consignor_data_clean[pd.notnull(consignor_data['unloading_in_time'])]
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
consignor_data_clean.isnull().sum()/consignor_data_clean.shape[0] * 100
# Out:
# id                            0.000000
# trucker_id                    0.000000
# truck_id                      0.000000
# shipper_id                    6.442929
# consigner_id                  6.335248
# consignee_id                100.000000
# source                      100.000000
# data_string                   0.000000
# invoice_no                    1.453697
# lorry_receipt_no            100.000000
# consigner_name                0.000000
# consignee_name                0.000000
# transporter                   0.000000
# eta                           0.000000
# origin                        0.000000
# destination                   0.000000
# loading_area                100.000000
# start_date                    0.000000
# end_date                    100.000000
# closed_by                     1.633166
# closed_date                  14.178033
# is_active                     0.000000
# created_at                    0.000000
# updated_at                    0.000000
# slug                          0.000000
# card_no                      85.750179
# vehicle_entry_time           20.513281
# vehicle_exit_time            21.338837
# vehicle_no                    0.000000
# status                        4.809763
# state                         0.233309
# consigner_pincode_id        100.000000
# consignee_pincode_id         63.603733
# consignee_lat                 0.215363
# consignee_long                0.215363
# closure_reason                1.633166
# consigner_code                0.000000
# consigner_lat                 0.000000
# consigner_long                0.000000
# loading_in_time               0.000000
# loading_out_time              0.000000
# unloading_in_time             0.000000
# unloading_out_time            7.232592
# IMEI                        100.000000
# loading_poi_id               64.447236
# unloading_poi_id             68.790380
# unloading_poi_history_id    100.000000
# loading_poi_history_id      100.000000
# dtype: float64

# %%
consignor_data_clean.shape
# Out:
# (5572, 48)

# %%
consignor_data.shape
# Out:
# (21165, 48)

# %%
consignor_data_clean = consignor_data_clean[consignor_data_clean['consigner_code'] != 'TATA STEEL']

# %%
consignor_data_clean['eta']
# Out:
# 6985     2017-08-01 00:00:00
# 6986     2017-08-01 00:00:00
# 6987     2017-08-01 00:00:00
# 6988     2017-08-01 00:00:00
# 6989     2017-08-01 00:00:00
# 6990     2017-08-01 00:00:00
# 6991     2017-08-01 00:00:00
# 6992     2017-08-01 00:00:00
# 6993     2017-08-01 00:00:00
# 6994     2017-08-01 00:00:00
# 6995     2017-08-01 00:00:00
# 6996     2017-08-01 00:00:00
# 6997     2017-08-01 00:00:00
# 6998     2017-08-01 00:00:00
# 6999     2017-08-01 00:00:00
# 7000     2017-08-01 00:00:00
# 7001     2017-08-01 00:00:00
# 7002     2017-08-01 00:00:00
# 7018     2017-08-02 00:00:00
# 7019     2017-08-02 00:00:00
# 7020     2017-08-02 00:00:00
# 7021     2017-08-02 00:00:00
# 7022     2017-08-02 00:00:00
# 7023     2017-08-02 00:00:00
# 7038     2017-08-02 00:00:00
# 7039     2017-08-02 00:00:00
# 7040     2017-08-02 00:00:00
# 7041     2017-08-02 00:00:00
# 7042     2017-08-02 00:00:00
# 7043     2017-08-02 00:00:00
#                 ...
# 20815    2017-12-02 00:00:00
# 20816    2017-12-02 00:00:00
# 20830    2017-12-04 00:00:00
# 20831    2017-12-07 00:00:00
# 20836    2017-11-30 00:00:00
# 20849    2017-12-08 00:00:00
# 20879    2017-12-05 00:00:00
# 20880    2017-12-05 00:00:00
# 20883    2017-12-03 00:00:00
# 20884    2017-12-03 00:00:00
# 20887    2017-12-03 00:00:00
# 20888    2017-12-03 00:00:00
# 20889    2017-12-03 00:00:00
# 20895    2017-12-03 00:00:00
# 20912    2017-12-03 00:00:00
# 20931    2017-12-06 00:00:00
# 20935    2017-12-06 00:00:00
# 20937    2017-12-06 00:00:00
# 20944    2017-12-06 00:00:00
# 20954    2017-12-06 00:00:00
# 20970    2017-12-03 00:00:00
# 20973    2017-12-03 00:00:00
# 20975    2017-12-04 00:00:00
# 20976    2017-12-04 00:00:00
# 20980    2017-12-03 00:00:00
# 20981    2017-12-03 00:00:00
# 20982    2017-12-03 00:00:00
# 20984    2017-12-03 00:00:00
# 21000    2017-12-04 00:00:00
# 21086    2017-12-03 00:00:00
# Name: eta, Length: 5216, dtype: object

# %%
consignor_data_clean['recorded_transit'] = consignor_data_clean['eta'] - consignor_data_clean['start_date']

# %%
consignor_data_clean[['eta','start_date','recorded_transit']]
# Out:
#                        eta           start_date recorded_transit
# 6985   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6986   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6987   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6988   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6989   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6990   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6991   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6992   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6993   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6994   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6995   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6996   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6997   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6998   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 6999   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 7000   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 7001   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 7002   2017-08-01 00:00:00  2017-07-31 00:00:00  1 days 00:00:00
# 7018   2017-08-02 00:00:00  2017-08-01 11:00:12  0 days 12:59:48
# 7019   2017-08-02 00:00:00  2017-08-01 00:00:00  1 days 00:00:00
# 7020   2017-08-02 00:00:00  2017-08-01 00:00:00  1 days 00:00:00
# 7021   2017-08-02 00:00:00  2017-08-01 00:00:00  1 days 00:00:00
# 7022   2017-08-02 00:00:00  2017-08-01 00:00:00  1 days 00:00:00
# 7023   2017-08-02 00:00:00  2017-08-01 00:00:00  1 days 00:00:00
# 7038   2017-08-02 00:00:00  2017-08-01 00:00:00  1 days 00:00:00
# 7039   2017-08-02 00:00:00  2017-08-01 00:00:00  1 days 00:00:00
# 7040   2017-08-02 00:00:00  2017-08-01 00:00:00  1 days 00:00:00
# 7041   2017-08-02 00:00:00  2017-08-01 00:00:00  1 days 00:00:00
# 7042   2017-08-02 00:00:00  2017-08-01 00:00:00  1 days 00:00:00
# 7043   2017-08-02 00:00:00  2017-08-01 00:00:00  1 days 00:00:00
# ...                    ...                  ...              ...
# 20815  2017-12-02 00:00:00  2017-11-30 00:00:00  2 days 00:00:00
# 20816  2017-12-02 00:00:00  2017-11-30 00:00:00  2 days 00:00:00
# 20830  2017-12-04 00:00:00  2017-11-30 00:00:00  4 days 00:00:00
# 20831  2017-12-07 00:00:00  2017-11-30 00:00:00  7 days 00:00:00
# 20836  2017-11-30 00:00:00  2017-11-30 00:00:00  0 days 00:00:00
# 20849  2017-12-08 00:00:00  2017-12-01 00:00:00  7 days 00:00:00
# 20879  2017-12-05 00:00:00  2017-12-01 00:00:00  4 days 00:00:00
# 20880  2017-12-05 00:00:00  2017-12-01 00:00:00  4 days 00:00:00
# 20883  2017-12-03 00:00:00  2017-12-01 00:00:00  2 days 00:00:00
# 20884  2017-12-03 00:00:00  2017-12-01 00:00:00  2 days 00:00:00
# 20887  2017-12-03 00:00:00  2017-12-01 00:00:00  2 days 00:00:00
# 20888  2017-12-03 00:00:00  2017-12-01 00:00:00  2 days 00:00:00
# 20889  2017-12-03 00:00:00  2017-12-01 00:00:00  2 days 00:00:00
# 20895  2017-12-03 00:00:00  2017-12-01 00:00:00  2 days 00:00:00
# 20912  2017-12-03 00:00:00  2017-12-01 00:00:00  2 days 00:00:00
# 20931  2017-12-06 00:00:00  2017-12-02 00:00:00  4 days 00:00:00
# 20935  2017-12-06 00:00:00  2017-12-02 00:00:00  4 days 00:00:00
# 20937  2017-12-06 00:00:00  2017-12-02 00:00:00  4 days 00:00:00
# 20944  2017-12-06 00:00:00  2017-12-02 00:00:00  4 days 00:00:00
# 20954  2017-12-06 00:00:00  2017-12-02 00:00:00  4 days 00:00:00
# 20970  2017-12-03 00:00:00  2017-12-02 00:00:00  1 days 00:00:00
# 20973  2017-12-03 00:00:00  2017-12-02 00:00:00  1 days 00:00:00
# 20975  2017-12-04 00:00:00  2017-12-02 00:00:00  2 days 00:00:00
# 20976  2017-12-04 00:00:00  2017-12-02 00:00:00  2 days 00:00:00
# 20980  2017-12-03 00:00:00  2017-12-02 00:00:00  1 days 00:00:00
# 20981  2017-12-03 00:00:00  2017-12-02 00:00:00  1 days 00:00:00
# 20982  2017-12-03 00:00:00  2017-12-02 00:00:00  1 days 00:00:00
# 20984  2017-12-03 00:00:00  2017-12-02 00:00:00  1 days 00:00:00
# 21000  2017-12-04 00:00:00  2017-12-02 00:00:00  2 days 00:00:00
# 21086  2017-12-03 00:00:00  2017-12-02 00:00:00  1 days 00:00:00
#
# [5216 rows x 3 columns]

# %%
consignor_data_clean['actual_transit'] = consignor_data_clean['unloading_in_time'] - consignor_data_clean['loading_out_time']

# %%
consignor_data_clean['delivery'] = consignor_data_clean['recorded_transit'] - consignor_data_clean['actual_transit']

# %%
((consignor_data_clean['delivery'] >= '0 days 00:00:00') & (consignor_data_clean['delivery'] <= '0 days 00:11:00')).sum()
# Out:
# 0

# %%
consignor_data_clean['delivery_status'] = ''

# %%
((consignor_data_clean['delivery'] < '0 days 00:00:00')).sum()
# Out:
# 385

# %%
((consignor_data_clean['delivery'] >= '0 days 00:00:00') & (consignor_data_clean['delivery'] <= '0 days 24:00:00')).sum()
# Out:
# 1715

# %%
((consignor_data_clean['delivery'] > '0 days 24:00:00')).sum()
# Out:
# 3116

# %%
consignor_data_clean.loc[consignor_data_clean.delivery < '0 days 00:00:00', 'delivery_status'] = 'early'

# %%
consignor_data_clean.loc[(consignor_data_clean['delivery'] >= '0 days 00:00:00') & (consignor_data_clean['delivery'] <= '0 days 24:00:00'), 'delivery_status'] = 'on-time'

# %%
consignor_data_clean.loc[(consignor_data_clean['delivery'] > '0 days 24:00:00'), 'delivery_status'] = 'late'

# %%
consignor_data_clean['delivery_status'].value_counts()
# Out:
# late       3116
# on-time    1715
# early       385
# Name: delivery_status, dtype: int64

# %%
consignor_data_clean.sort_values(['origin','destination'])
# Out:
#           id  trucker_id  truck_id  shipper_id  consigner_id consignee_id  \
# 16932  17230         222      4309       158.0           3.0         None
# 17418  17723         222      5131       158.0           3.0         None
# 17554  17859         222      5164       158.0           3.0         None
# 16881  17175         222      2601       158.0           3.0         None
# 16882  17176         222      3295       158.0           3.0         None
# 20582  20909         222      4823       158.0           3.0         None
# 14543  14791         222      4228       158.0           3.0         None
# 14780  15028         222      4309       158.0           3.0         None
# 14861  15109         222       728       158.0           3.0         None
# 14935  15183         222       727       158.0           3.0         None
# 15030  15278         222      4380       158.0           3.0         None
# 15701  15988         222      4620       158.0           3.0         None
# 15702  15989         222      4309       158.0           3.0         None
# 15787  16074         222      3295       158.0           3.0         None
# 15788  16075         222      4641       158.0           3.0         None
# 15833  16120         222      4653       158.0           3.0         None
# 16230  16522         222      4787       158.0           3.0         None
# 16310  16603         222      4309       158.0           3.0         None
# 16330  16623         222      4823       158.0           3.0         None
# 16355  16648         222      4832       158.0           3.0         None
# 16596  16889         291      4559       158.0           3.0         None
# 16637  16930         222      4958       158.0           3.0         None
# 16638  16931         222       971       158.0           3.0         None
# 16720  17013         291      4545       158.0           3.0         None
# 17294  17599         222      4752       158.0           3.0         None
# 17302  17607         222      4380       158.0           3.0         None
# 17588  17893         222      4641       158.0           3.0         None
# 17598  17903         222      5179       158.0           3.0         None
# 17699  18004         222      5205       158.0           3.0         None
# 17702  18007         222      5206       158.0           3.0         None
# ...      ...         ...       ...         ...           ...          ...
# 19904  20230           2      5771       225.0          99.0         None
# 19905  20231           2      5772       225.0          99.0         None
# 19508  19827           2      5640       228.0          99.0         None
# 19509  19828           2      5641       228.0          99.0         None
# 19582  19903           2      5663       228.0          99.0         None
# 19583  19904           2      5664       228.0          99.0         None
# 19726  20047           2      5704       228.0          99.0         None
# 19727  20048           2      5705       228.0          99.0         None
# 19738  20059           2      5709       228.0          99.0         None
# 19906  20232           2      5773       228.0          99.0         None
# 19907  20233           2      5774       228.0          99.0         None
# 19543  19862           2      5649       229.0          99.0         None
# 19544  19863           2      5650       229.0          99.0         None
# 19739  20060           2      5710       226.0          99.0         None
# 19740  20061           2      5711       226.0          99.0         None
# 19789  20115           2      5732       226.0          99.0         None
# 19790  20116           2      5733       226.0          99.0         None
# 19899  20225           2      5767       226.0          99.0         None
# 20251  20578           2      5767       226.0          99.0         None
# 20256  20583           2      5872       226.0          99.0         None
# 20257  20584           2      5873       226.0          99.0         None
# 19451  19770           2      5633       225.0          99.0         None
# 19452  19771           2      5624       225.0          99.0         None
# 19773  20099           2      5727       229.0          99.0         None
# 19775  20101           2      5728       229.0          99.0         None
# 19641  19962           2      5675       226.0          99.0         None
# 19581  19902           2      5661       228.0          99.0         None
# 19449  19768           2      5631       224.0          99.0         None
# 19450  19769           2      5632       224.0          99.0         None
# 20055  20381           2      5816       228.0          99.0         None
#
#       source                                        data_string invoice_no  \
# 16932   None  {"id":7592,"truck_number":"OD05J9266","chassis...    temps96
# 17418   None  {"id":7820,"truck_number":"OD05AE2707","chassi...    temps34
# 17554   None  {"id":7910,"truck_number":"OD05T9045","chassis...    temps87
# 16881   None  {"id":7558,"truck_number":"OD05AC5357","chassi...     temps8
# 16882   None  {"id":7559,"truck_number":"OD05AC7040","chassi...    temps47
# 20582   None  {"id":9923,"truck_number":"OD11A2306","chassis...    temps91
# 14543   None  {"id":5912,"truck_number":"OR04H6196","chassis...    temps91
# 14780   None  {"id":6080,"truck_number":"OD05J9266","chassis...    temps51
# 14861   None  {"id":6122,"truck_number":"OD05Q6099","chassis...    temps79
# 14935   None  {"id":6172,"truck_number":"OD05Q6856","chassis...    temps53
# 15030   None  {"id":6232,"truck_number":"OD05Z2005","chassis...    temps40
# 15701   None  {"id":6667,"truck_number":"OD05AD6485","chassi...    temps72
# 15702   None  {"id":6668,"truck_number":"OD05J9266","chassis...     temps6
# 15787   None  {"id":6714,"truck_number":"OD05AC7040","chassi...     temps5
# 15788   None  {"id":6715,"truck_number":"OD05X0277","chassis...    temps44
# 15833   None  {"id":6747,"truck_number":"OR05AE4849","chassi...    temps34
# 16230   None  {"id":7057,"truck_number":"OR05AJ1575","chassi...     temps6
# 16310   None  {"id":7140,"truck_number":"OD05J9266","chassis...    temps98
# 16330   None  {"id":7161,"truck_number":"OD11A2306","chassis...    temps70
# 16355   None  {"id":7187,"truck_number":"OD05AC5123","chassi...     temps6
# 16596   None  {"id":7368,"truck_number":"OD05J3030","chassis...    temps66
# 16637   None  {"id":7401,"truck_number":"OD05Z3045","chassis...    temps86
# 16638   None  {"id":7402,"truck_number":"OR05AQ9095","chassi...    temps76
# 16720   None  {"id":7461,"truck_number":"OD05Y2715","chassis...    temps40
# 17294   None  {"id":7754,"truck_number":"OR05AR4275","chassi...     temps4
# 17302   None  {"id":7759,"truck_number":"OD05Z2005","chassis...    temps36
# 17588   None  {"id":7942,"truck_number":"OD05X0277","chassis...    temps52
# 17598   None  {"id":7950,"truck_number":"OD05Q7607","chassis...    temps51
# 17699   None  {"id":8000,"truck_number":"OR09N3541","chassis...    temps74
# 17702   None  {"id":8002,"truck_number":"OR05AA6215","chassi...    temps13
# ...      ...                                                ...        ...
# 19904   None  {"id":9450,"truck_number":"RJ19GE8518","chassi...    temps24
# 19905   None  {"id":9450,"truck_number":"RJ19GE8518","chassi...    temps60
# 19508   None  {"id":9175,"truck_number":"MH43F2618","chassis...    temps17
# 19509   None  {"id":9175,"truck_number":"MH43F2618","chassis...    temps53
# 19582   None  {"id":9232,"truck_number":"MH04P6212","chassis...    temps78
# 19583   None  {"id":9232,"truck_number":"MH04P6212","chassis...    temps66
# 19726   None  {"id":9336,"truck_number":"MH04FU9399","chassi...    temps26
# 19727   None  {"id":9336,"truck_number":"MH04FU9399","chassi...    temps80
# 19738   None  {"id":9342,"truck_number":"MH04BG8096","chassi...    temps39
# 19906   None  {"id":9451,"truck_number":"MH43U4405","chassis...     temps0
# 19907   None  {"id":9451,"truck_number":"MH43U4405","chassis...    temps53
# 19543   None  {"id":9204,"truck_number":"MH46AR2060","chassi...    temps54
# 19544   None  {"id":9204,"truck_number":"MH46AR2060","chassi...    temps50
# 19739   None  {"id":9343,"truck_number":"MH06BD0272","chassi...    temps93
# 19740   None  {"id":9343,"truck_number":"MH06BD0272","chassi...    temps90
# 19789   None  {"id":9390,"truck_number":"MH05AM3175","chassi...     temps3
# 19790   None  {"id":9390,"truck_number":"MH05AM3175","chassi...     temps3
# 19899   None  {"id":9448,"truck_number":"MH05AM2015","chassi...    temps40
# 20251   None  {"id":9707,"truck_number":"MH05AM2015","chassi...    temps56
# 20256   None  {"id":9708,"truck_number":"MH05DK0362","chassi...    temps28
# 20257   None  {"id":9708,"truck_number":"MH05DK0362","chassi...    temps11
# 19451   None  {"id":9151,"truck_number":"MH04GR6528","chassi...     temps3
# 19452   None  {"id":9151,"truck_number":"MH04GR6528","chassi...    temps68
# 19773   None  {"id":9376,"truck_number":"MH46H1378","chassis...    temps24
# 19775   None  {"id":9376,"truck_number":"MH46H1378","chassis...    temps60
# 19641   None  {"id":9261,"truck_number":"RJ22GA9444","chassi...    temps79
# 19581   None  {"id":9231,"truck_number":"MH04FJ9919","chassi...    temps96
# 19449   None  {"id":9150,"truck_number":"TN52L3157","chassis...    temps52
# 19450   None  {"id":9150,"truck_number":"TN52L3157","chassis...     temps8
# 20055   None  {"id":9565,"truck_number":"MH43U2620","chassis...    temps26
#
#       lorry_receipt_no       ...        unloading_out_time  IMEI  \
# 16932             None       ...       2017-11-03 15:55:41  None
# 17418             None       ...       2017-11-07 10:19:40  None
# 17554             None       ...       2017-11-08 08:42:25  None
# 16881             None       ...       2017-11-02 05:31:38  None
# 16882             None       ...       2017-11-02 05:29:42  None
# 20582             None       ...       2017-12-04 12:33:58  None
# 14543             None       ...       2017-10-06 14:41:59  None
# 14780             None       ...       2017-10-09 11:51:12  None
# 14861             None       ...       2017-10-09 17:19:44  None
# 14935             None       ...       2017-10-09 16:32:41  None
# 15030             None       ...       2017-10-10 13:30:56  None
# 15701             None       ...       2017-10-15 13:55:33  None
# 15702             None       ...       2017-10-15 16:01:50  None
# 15787             None       ...       2017-10-16 12:49:25  None
# 15788             None       ...       2017-10-16 12:31:40  None
# 15833             None       ...       2017-10-16 12:15:29  None
# 16230             None       ...       2017-10-23 17:03:52  None
# 16310             None       ...       2017-10-24 19:02:50  None
# 16330             None       ...       2017-10-24 23:38:47  None
# 16355             None       ...       2017-10-23 03:12:05  None
# 16596             None       ...       2017-10-26 19:22:23  None
# 16637             None       ...       2017-10-26 19:47:22  None
# 16638             None       ...       2017-10-26 19:47:14  None
# 16720             None       ...       2017-10-27 19:44:27  None
# 17294             None       ...       2017-11-01 13:28:21  None
# 17302             None       ...       2017-11-01 13:23:10  None
# 17588             None       ...       2017-11-04 13:28:08  None
# 17598             None       ...       2017-11-04 13:22:50  None
# 17699             None       ...       2017-11-05 05:12:39  None
# 17702             None       ...       2017-11-06 04:28:53  None
# ...                ...       ...                       ...   ...
# 19904             None       ...       2017-11-25 18:32:39  None
# 19905             None       ...       2017-11-25 20:34:50  None
# 19508             None       ...       2017-11-23 14:59:27  None
# 19509             None       ...       2017-11-23 13:31:57  None
# 19582             None       ...       2017-11-23 10:52:46  None
# 19583             None       ...       2017-11-23 15:34:20  None
# 19726             None       ...       2017-11-23 12:15:06  None
# 19727             None       ...       2017-11-23 12:33:16  None
# 19738             None       ...       2017-11-23 06:10:22  None
# 19906             None       ...       2017-11-25 14:06:43  None
# 19907             None       ...       2017-11-25 15:36:14  None
# 19543             None       ...       2017-11-23 04:28:00  None
# 19544             None       ...       2017-11-23 08:31:50  None
# 19739             None       ...       2017-11-26 07:11:05  None
# 19740             None       ...       2017-11-26 07:34:20  None
# 19789             None       ...       2017-11-24 07:04:17  None
# 19790             None       ...       2017-11-24 09:35:12  None
# 19899             None       ...       2017-11-24 20:48:58  None
# 20251             None       ...       2017-11-27 21:03:39  None
# 20256             None       ...       2017-11-26 21:19:03  None
# 20257             None       ...       2017-11-26 22:38:56  None
# 19451             None       ...       2017-11-23 11:13:34  None
# 19452             None       ...       2017-11-23 17:32:06  None
# 19773             None       ...       2017-11-23 18:08:52  None
# 19775             None       ...       2017-11-24 22:34:54  None
# 19641             None       ...       2017-11-24 14:13:56  None
# 19581             None       ...       2017-11-23 00:55:38  None
# 19449             None       ...       2017-11-23 14:51:21  None
# 19450             None       ...       2017-11-23 15:32:06  None
# 20055             None       ...       2017-11-28 05:32:17  None
#
#       loading_poi_id unloading_poi_id unloading_poi_history_id  \
# 16932            NaN              NaN                     None
# 17418         5485.0           5644.0                     None
# 17554         5485.0           5644.0                     None
# 16881            NaN              NaN                     None
# 16882            NaN              NaN                     None
# 20582         5485.0           5807.0                     None
# 14543            NaN              NaN                     None
# 14780            NaN              NaN                     None
# 14861            NaN              NaN                     None
# 14935            NaN              NaN                     None
# 15030            NaN              NaN                     None
# 15701            NaN              NaN                     None
# 15702            NaN              NaN                     None
# 15787            NaN              NaN                     None
# 15788            NaN              NaN                     None
# 15833            NaN              NaN                     None
# 16230            NaN              NaN                     None
# 16310            NaN              NaN                     None
# 16330            NaN              NaN                     None
# 16355            NaN              NaN                     None
# 16596            NaN              NaN                     None
# 16637            NaN              NaN                     None
# 16638            NaN              NaN                     None
# 16720            NaN              NaN                     None
# 17294            NaN              NaN                     None
# 17302            NaN              NaN                     None
# 17588            NaN              NaN                     None
# 17598         5485.0           5604.0                     None
# 17699         5485.0           5604.0                     None
# 17702         5485.0           5604.0                     None
# ...              ...              ...                      ...
# 19904         6628.0           7016.0                     None
# 19905         6644.0           7016.0                     None
# 19508         6628.0           6645.0                     None
# 19509         6644.0           6645.0                     None
# 19582         6628.0           6645.0                     None
# 19583         6644.0           6645.0                     None
# 19726         6628.0           6645.0                     None
# 19727         6628.0           6645.0                     None
# 19738         6628.0           6645.0                     None
# 19906         6628.0           6645.0                     None
# 19907         6644.0           6645.0                     None
# 19543         6628.0           6646.0                     None
# 19544         6644.0           6646.0                     None
# 19739         6628.0           6646.0                     None
# 19740         6628.0           6646.0                     None
# 19789         6628.0           6646.0                     None
# 19790         6644.0           6646.0                     None
# 19899         6628.0           6646.0                     None
# 20251         6628.0           6646.0                     None
# 20256         6628.0           6646.0                     None
# 20257         6644.0           6646.0                     None
# 19451         6628.0           6641.0                     None
# 19452         6644.0           6641.0                     None
# 19773         6628.0           7439.0                     None
# 19775         6644.0           7439.0                     None
# 19641         6628.0           6881.0                     None
# 19581         6628.0           7436.0                     None
# 19449         6628.0           6643.0                     None
# 19450         6644.0           6643.0                     None
# 20055         6628.0           7435.0                     None
#
#       loading_poi_history_id recorded_transit    actual_transit  \
# 16932                   None  5 days 00:00:00   4 days 21:03:41
# 17418                   None  5 days 00:00:00   6 days 15:28:09
# 17554                   None  5 days 00:00:00   5 days 09:52:18
# 16881                   None  5 days 00:00:00   6 days 09:02:50
# 16882                   None  5 days 00:00:00   6 days 09:02:21
# 20582                   None  5 days 00:00:00   5 days 14:51:55
# 14543                   None  2 days 00:00:00   0 days 19:32:30
# 14780                   None  2 days 00:00:00   1 days 15:49:13
# 14861                   None  2 days 00:00:00   1 days 03:43:41
# 14935                   None  2 days 00:00:00   1 days 03:44:59
# 15030                   None  2 days 00:00:00   1 days 08:58:22
# 15701                   None  2 days 00:00:00   1 days 09:43:28
# 15702                   None  2 days 00:00:00   0 days 21:01:40
# 15787                   None  2 days 00:00:00   1 days 05:43:02
# 15788                   None  2 days 00:00:00   1 days 09:33:04
# 15833                   None  2 days 00:00:00   1 days 06:25:31
# 16230                   None  2 days 00:00:00   1 days 06:41:47
# 16310                   None  3 days 12:49:11   0 days 18:05:30
# 16330                   None  3 days 09:40:17   0 days 21:42:47
# 16355                   None  2 days 00:00:00   1 days 06:03:14
# 16596                   None  2 days 21:44:22   1 days 03:05:34
# 16637                   None  2 days 00:00:00   0 days 18:00:37
# 16638                   None  2 days 21:44:44   1 days 04:38:30
# 16720                   None  2 days 00:00:00   1 days 05:57:52
# 17294                   None  2 days 00:00:00   1 days 07:50:55
# 17302                   None  2 days 00:00:00   1 days 08:06:09
# 17588                   None  2 days 00:00:00   0 days 16:03:09
# 17598                   None  2 days 00:00:00   1 days 07:34:18
# 17699                   None  2 days 00:00:00   1 days 09:13:51
# 17702                   None  2 days 00:00:00   2 days 08:18:08
# ...                      ...              ...               ...
# 19904                   None  4 days 00:00:00   0 days 18:05:34
# 19905                   None  4 days 00:00:00   0 days 17:00:50
# 19508                   None  2 days 00:00:00   1 days 03:54:29
# 19509                   None  2 days 00:00:00 -2 days +00:45:45
# 19582                   None  2 days 00:00:00   1 days 05:37:56
# 19583                   None  2 days 00:00:00   0 days 00:00:00
# 19726                   None  2 days 00:00:00   0 days 01:07:44
# 19727                   None  2 days 00:00:00   0 days 13:01:38
# 19738                   None  2 days 00:00:00   0 days 09:18:40
# 19906                   None  2 days 00:00:00   1 days 08:06:26
# 19907                   None  2 days 00:00:00   1 days 11:57:18
# 19543                   None  2 days 00:00:00   1 days 04:14:56
# 19544                   None  2 days 00:00:00   0 days 03:00:18
# 19739                   None  2 days 00:00:00   0 days 07:41:47
# 19740                   None  2 days 00:00:00 -1 days +18:30:53
# 19789                   None  2 days 00:00:00   0 days 12:09:34
# 19790                   None  2 days 00:00:00   0 days 10:59:23
# 19899                   None  2 days 00:00:00   0 days 15:32:27
# 20251                   None  2 days 00:00:00   0 days 15:13:53
# 20256                   None  2 days 00:00:00   0 days 10:30:53
# 20257                   None  2 days 00:00:00   0 days 07:00:17
# 19451                   None  4 days 00:00:00   2 days 03:14:17
# 19452                   None  4 days 00:00:00   2 days 17:00:03
# 19773                   None  2 days 00:00:00   0 days 10:21:40
# 19775                   None  2 days 00:00:00   0 days 05:58:12
# 19641                   None  2 days 00:00:00   1 days 16:29:20
# 19581                   None  2 days 00:00:00 -1 days +17:10:22
# 19449                   None  6 days 00:00:00   2 days 05:26:41
# 19450                   None  6 days 00:00:00   1 days 08:15:38
# 20055                   None  2 days 00:00:00 -1 days +12:32:01
#
#                delivery delivery_status
# 16932   0 days 02:56:19         on-time
# 17418 -2 days +08:31:51           early
# 17554 -1 days +14:07:42           early
# 16881 -2 days +14:57:10           early
# 16882 -2 days +14:57:39           early
# 20582 -1 days +09:08:05           early
# 14543   1 days 04:27:30            late
# 14780   0 days 08:10:47         on-time
# 14861   0 days 20:16:19         on-time
# 14935   0 days 20:15:01         on-time
# 15030   0 days 15:01:38         on-time
# 15701   0 days 14:16:32         on-time
# 15702   1 days 02:58:20            late
# 15787   0 days 18:16:58         on-time
# 15788   0 days 14:26:56         on-time
# 15833   0 days 17:34:29         on-time
# 16230   0 days 17:18:13         on-time
# 16310   2 days 18:43:41            late
# 16330   2 days 11:57:30            late
# 16355   0 days 17:56:46         on-time
# 16596   1 days 18:38:48            late
# 16637   1 days 05:59:23            late
# 16638   1 days 17:06:14            late
# 16720   0 days 18:02:08         on-time
# 17294   0 days 16:09:05         on-time
# 17302   0 days 15:53:51         on-time
# 17588   1 days 07:56:51            late
# 17598   0 days 16:25:42         on-time
# 17699   0 days 14:46:09         on-time
# 17702 -1 days +15:41:52           early
# ...                 ...             ...
# 19904   3 days 05:54:26            late
# 19905   3 days 06:59:10            late
# 19508   0 days 20:05:31         on-time
# 19509   3 days 23:14:15            late
# 19582   0 days 18:22:04         on-time
# 19583   2 days 00:00:00            late
# 19726   1 days 22:52:16            late
# 19727   1 days 10:58:22            late
# 19738   1 days 14:41:20            late
# 19906   0 days 15:53:34         on-time
# 19907   0 days 12:02:42         on-time
# 19543   0 days 19:45:04         on-time
# 19544   1 days 20:59:42            late
# 19739   1 days 16:18:13            late
# 19740   2 days 05:29:07            late
# 19789   1 days 11:50:26            late
# 19790   1 days 13:00:37            late
# 19899   1 days 08:27:33            late
# 20251   1 days 08:46:07            late
# 20256   1 days 13:29:07            late
# 20257   1 days 16:59:43            late
# 19451   1 days 20:45:43            late
# 19452   1 days 06:59:57            late
# 19773   1 days 13:38:20            late
# 19775   1 days 18:01:48            late
# 19641   0 days 07:30:40         on-time
# 19581   2 days 06:49:38            late
# 19449   3 days 18:33:19            late
# 19450   4 days 15:44:22            late
# 20055   2 days 11:27:59            late
#
# [5216 rows x 52 columns]

# %%
consignor_data_clean['total_early'] = 0
consignor_data_clean['total_on_time'] = 0
consignor_data_clean['total_late'] = 0

# %%
def stats_of_routes(orig, des):
    early = 0
    on_time = 0
    late = 0
    early = consignor_data_clean[consignor_data_clean['origin'] == orig][consignor_data_clean['destination'] == des][consignor_data_clean['delivery_status'] == 'early'].shape[0]    
    on_time = consignor_data_clean[consignor_data_clean['origin'] == orig][consignor_data_clean['destination'] == des][consignor_data_clean['delivery_status'] == 'on-time'].shape[0]    
    late = consignor_data_clean[consignor_data_clean['origin'] == orig][consignor_data_clean['destination'] == des][consignor_data_clean['delivery_status'] == 'late'].shape[0]    
    
    consignor_data_clean.total_early = np.where((consignor_data_clean.origin == orig) & (consignor_data_clean.destination == des), early, consignor_data_clean['total_early']).astype(int) 
    consignor_data_clean.total_on_time = np.where((consignor_data_clean.origin == orig) & (consignor_data_clean.destination == des), on_time, consignor_data_clean['total_on_time']).astype(int) 
    consignor_data_clean.total_late = np.where((consignor_data_clean.origin == orig) & (consignor_data_clean.destination == des), late, consignor_data_clean['total_late']).astype(int) 

#     sns.countplot(x="delivery_status", data=test)
#     plt.show()

# %%
origin_list = consignor_data_clean['origin'].unique().tolist()

# %%
dest_list = consignor_data_clean['destination'].unique().tolist()

# %%
for origi in origin_list:
    for desti in dest_list:
        if consignor_data_clean[consignor_data_clean.origin == origi][consignor_data_clean.destination == desti].shape[0] > 0: 
            stats_of_routes(origi,desti)
        else:
            continue
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:6: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:7: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
consignor_data_clean[['delivery_status','origin','destination','delivery','total_early','total_on_time','total_late']]
# Out:
#       delivery_status      origin    destination          delivery  \
# 6985          on-time    Garividi  Visakhapatnam   0 days 22:30:30
# 6986             late    Garividi  Visakhapatnam   2 days 15:30:30
# 6987          on-time    Garividi  Visakhapatnam   0 days 22:12:19
# 6988          on-time    Garividi  Visakhapatnam   0 days 22:24:39
# 6989          on-time    Garividi  Visakhapatnam   0 days 22:22:53
# 6990          on-time    Garividi  Visakhapatnam   0 days 22:13:44
# 6991          on-time    Garividi  Visakhapatnam   0 days 22:13:05
# 6992          on-time    Garividi  Visakhapatnam   0 days 22:26:49
# 6993             late    Garividi  Visakhapatnam   2 days 12:22:54
# 6994             late    Garividi  Visakhapatnam  10 days 17:53:41
# 6995          on-time    Garividi  Visakhapatnam   0 days 22:03:47
# 6996          on-time    Garividi  Visakhapatnam   0 days 22:14:29
# 6997             late    Garividi  Visakhapatnam   6 days 23:16:44
# 6998          on-time    Garividi  Visakhapatnam   0 days 22:19:00
# 6999          on-time    Garividi  Visakhapatnam   0 days 22:30:30
# 7000          on-time    Garividi  Visakhapatnam   0 days 11:15:30
# 7001          on-time    Garividi  Visakhapatnam   0 days 04:42:26
# 7002          on-time    Garividi  Visakhapatnam   0 days 22:22:50
# 7018             late       Noida         Nagpur  15 days 00:00:49
# 7019          on-time    Bamnipal         Jajpur   0 days 23:24:13
# 7020          on-time    Bamnipal         Jajpur   0 days 23:22:01
# 7021          on-time    Bamnipal         Jajpur   0 days 23:23:43
# 7022          on-time    Bamnipal         Jajpur   0 days 23:06:40
# 7023          on-time    Bamnipal         Jajpur   0 days 23:21:36
# 7038          on-time    Bamnipal         Jajpur   0 days 22:47:07
# 7039          on-time    Bamnipal         Jajpur   0 days 23:13:53
# 7040          on-time    Bamnipal         Jajpur   0 days 23:23:03
# 7041          on-time    Bamnipal         Jajpur   0 days 23:13:39
# 7042          on-time    Bamnipal         Jajpur   0 days 23:05:34
# 7043          on-time    Bamnipal         Jajpur   0 days 23:15:34
# ...               ...         ...            ...               ...
# 20815         on-time    Bamnipal  Visakhapatnam   0 days 14:36:43
# 20816         on-time    Bamnipal  Visakhapatnam   0 days 16:10:29
# 20830            late  Jamshedpur          PATNA   1 days 21:39:07
# 20831            late  Jamshedpur          KORBA   5 days 10:27:02
# 20836           early     Garbham  Visakhapatnam -1 days +18:57:52
# 20849            late  Jamshedpur          KORBA   4 days 12:33:36
# 20879            late  Jamshedpur        KOLKATA   3 days 16:54:43
# 20880            late  Jamshedpur        KOLKATA   3 days 05:19:17
# 20883         on-time   Dhenkanal  Visakhapatnam   0 days 14:06:18
# 20884         on-time   Dhenkanal  Visakhapatnam   0 days 14:35:33
# 20887         on-time   Dhenkanal  Visakhapatnam   0 days 13:17:55
# 20888            late   Dhenkanal  Visakhapatnam   1 days 07:57:51
# 20889           early   Dhenkanal  Visakhapatnam -1 days +22:10:19
# 20895         on-time     Bamaloi  Visakhapatnam   0 days 17:29:23
# 20912         on-time     Bamaloi  Visakhapatnam   0 days 17:29:23
# 20931            late  Jamshedpur        KOLKATA   3 days 09:55:24
# 20935            late  Jamshedpur         HOWRAH   3 days 01:54:04
# 20937            late  Jamshedpur        KOLKATA   3 days 05:41:37
# 20944            late  Jamshedpur        KOLKATA   2 days 05:33:35
# 20954            late  Jamshedpur        KOLKATA   3 days 05:05:35
# 20970         on-time    Bamnipal         Jajpur   0 days 23:22:36
# 20973         on-time    Bamnipal         Jajpur   0 days 23:22:01
# 20975         on-time   Dhenkanal  Visakhapatnam   0 days 13:03:28
# 20976         on-time   Dhenkanal  Visakhapatnam   0 days 10:10:31
# 20980         on-time    Bamnipal         Jajpur   0 days 23:31:09
# 20981         on-time    Bamnipal         Jajpur   0 days 23:20:24
# 20982         on-time    Bamnipal         Jajpur   0 days 23:15:31
# 20984         on-time    Bamnipal         Jajpur   0 days 23:17:53
# 21000         on-time   Dhenkanal  Visakhapatnam   0 days 14:52:13
# 21086         on-time    Garividi  Visakhapatnam   0 days 21:49:43
#
#        total_early  total_on_time  total_late
# 6985            11            347          66
# 6986            11            347          66
# 6987            11            347          66
# 6988            11            347          66
# 6989            11            347          66
# 6990            11            347          66
# 6991            11            347          66
# 6992            11            347          66
# 6993            11            347          66
# 6994            11            347          66
# 6995            11            347          66
# 6996            11            347          66
# 6997            11            347          66
# 6998            11            347          66
# 6999            11            347          66
# 7000            11            347          66
# 7001            11            347          66
# 7002            11            347          66
# 7018             0              0           1
# 7019             0            359           4
# 7020             0            359           4
# 7021             0            359           4
# 7022             0            359           4
# 7023             0            359           4
# 7038             0            359           4
# 7039             0            359           4
# 7040             0            359           4
# 7041             0            359           4
# 7042             0            359           4
# 7043             0            359           4
# ...            ...            ...         ...
# 20815            9             94          38
# 20816            9             94          38
# 20830            0              2          11
# 20831            0              0           2
# 20836           19              1           2
# 20849            0              0           2
# 20879            1              2          37
# 20880            1              2          37
# 20883           57            320         112
# 20884           57            320         112
# 20887           57            320         112
# 20888           57            320         112
# 20889           57            320         112
# 20895           19            134          17
# 20912           19            134          17
# 20931            1              2          37
# 20935            1              2          21
# 20937            1              2          37
# 20944            1              2          37
# 20954            1              2          37
# 20970            0            359           4
# 20973            0            359           4
# 20975           57            320         112
# 20976           57            320         112
# 20980            0            359           4
# 20981            0            359           4
# 20982            0            359           4
# 20984            0            359           4
# 21000           57            320         112
# 21086           11            347          66
#
# [5216 rows x 7 columns]

# %%
#to plot a graph based on delivery status between origin and destination

origin = raw_input("Please enter a valid origin: ")
destination = raw_input("Please enter a valid destination: ")

test = consignor_data_clean[consignor_data_clean['origin'] == origin][consignor_data_clean['destination'] == destination]                    
sns.countplot(x="delivery_status", data=test)
plt.show()
# Out:
# Please enter a valid origin: Bamnipal
# Please enter a valid destination: Jajpur
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:6: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
plot_route_delivery_df = consignor_data_clean[['origin','destination','total_early','total_on_time','total_late']]

# %%
plot_route_delivery_df.drop_duplicates(inplace=True)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plot_route_delivery_df['route'] = plot_route_delivery_df['origin'] + ' - ' + plot_route_delivery_df['destination']
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plot_route_delivery_df = plot_route_delivery_df.sort_values('total_late')

# %%
top_labels = ['early', 'on-time','late']

colors = ['rgba(123, 251, 2, 0.8)','rgba(255, 195, 0, 0.8)',
          'rgba(231, 76, 60, .8)']

x_data = []
for r in list(plot_route_delivery_df.route):
    lis = plot_route_delivery_df.loc[plot_route_delivery_df.route == r, ['total_early','total_on_time','total_late']].values.flatten().tolist()
    x_data.append(lis)

y_data = list(plot_route_delivery_df.route)


traces = []

for i in range(0, len(x_data[0])):
    for xd, yd in zip(x_data, y_data):
        traces.append(go.Bar(
            x=xd[i],
            y=yd,
            orientation='h',
            marker=dict(
                color=colors[i],
                line=dict(
                        color='rgb(248, 248, 249)',
                        width=1)
            )
        ))

layout = go.Layout(
    autosize=False,
    width=5000,
    height=5000,
    margin=go.Margin(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
        
    xaxis=dict(
        autorange=True,
        autotick=True,
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
        domain=[0.15, 1]
    ),
    yaxis=dict(
        autorange=True,
        autotick=False,
        tickwidth=10,
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
    ),
    barmode='stack',
    paper_bgcolor='rgb(248, 248, 255)',
    plot_bgcolor='rgb(248, 248, 255)',
    showlegend=False
)

annotations = []

for yd, xd in zip(y_data, x_data):
    # labeling the y-axis
    annotations.append(dict(xref='paper', yref='y',
                            x=0.14, y=yd,
                            xanchor='right',
                            text=str(yd),
                            font=dict(family='Arial', size=14,
                                      color='rgb(67, 67, 67)'),
                            showarrow=False, align='right'))
    # labeling the first percentage of each bar (x_axis)
    annotations.append(dict(xref='x', yref='y',
                            x=xd[0] / 2, y=yd,
                            text=str(xd[0]) + '%',
                            font=dict(family='Arial', size=14,
                                      color='rgb(248, 248, 255)'),
                            showarrow=False))
    # labeling the first Likert scale (on the top)
    if yd == y_data[-1]:
        annotations.append(dict(xref='x', yref='paper',
                                x=xd[0] / 2, y=1.1,
                                text=top_labels[0],
                                font=dict(family='Arial', size=14,
                                          color='rgb(67, 67, 67)'),
                                showarrow=False))
    space = xd[0]
    for i in range(1, len(xd)):
            # labeling the rest of percentages for each bar (x_axis)
            annotations.append(dict(xref='x', yref='y',
                                    x=space + (xd[i]/2), y=yd, 
                                    text=str(xd[i]) + '%',
                                    font=dict(family='Arial', size=14,
                                              color='rgb(248, 248, 255)'),
                                    showarrow=False))
            # labeling the Likert scale
            if yd == y_data[-1]:
                annotations.append(dict(xref='x', yref='paper',
                                        x=space + (xd[i]/2), y=1.1,
                                        text=top_labels[i],
                                        font=dict(family='Arial', size=14,
                                                  color='rgb(67, 67, 67)'),
                                        showarrow=False))
            space += xd[i]

layout['annotations'] = annotations

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='bar-colorscale')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mainakchain/8.embed" height="5000px" width="5000px"></iframe>

# %%
trace0 = go.Scatter(
    x = plot_route_delivery_df['route'],
    y = plot_route_delivery_df['total_early'],
    mode = 'lines',
    name = 'early'
)
trace1 = go.Scatter(
    x = plot_route_delivery_df['route'],
    y = plot_route_delivery_df['total_on_time'],
    mode = 'lines',
    name = 'on-time'
)
trace2 = go.Scatter(
    x = plot_route_delivery_df['route'],
    y = plot_route_delivery_df['total_late'],
    mode = 'lines',
    name = 'late'
)
data = [trace0, trace1, trace2]

layout = go.Layout(
    autosize=False,
    width=5000,
    height=8000,
    margin=go.Margin(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ))

cf.iplot(data, filename='line-chart-for-various-routes')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~mainakchain/0 or inside your plot.ly account where it is named 'line-chart-for-various-routes'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mainakchain/0.embed" height="525px" width="100%"></iframe>

# %%
test = plot_route_delivery_df = consignor_data_clean[['origin','destination','total_early','total_on_time','total_late','delivery']]

# %%
test['route'] = test['origin'] + " - " + test['destination']
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test['delivery_hours'] = test['delivery'].apply(lambda x: x.total_seconds()//3600)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
group_stats = {}
groupby_data = test.groupby('route')

for group in list(test['route'].unique()):
    data_from_group = groupby_data.get_group(group)['delivery']
    td = np.median(data_from_group.tolist())
    group_stats[group] = td.seconds//3600

# %%
test_shuffle_ = test_shuffle[test_shuffle.groupby('route').route.transform(len) > 1]

# %%
test_shuffle_.shape, test_shuffle.shape
# Out:
# ((5124, 2), (5216, 2))

# %%
np.random.seed(619517)

data_header = 'delivery_hours'
group_header = 'route'

group_stats = {}
groupby_data = test_shuffle_.groupby([group_header])

for group in list(test_shuffle_['route'].unique()):
    data_from_group = groupby_data.get_group(group)['delivery_hours']
    stat = np.median(list(data_from_group))
    group_stats[group] = stat

fig = ff.create_violin(test_shuffle_.dropna(), data_header='delivery_hours', group_header='route',
                       height=500, width=800, use_colorscale=True, group_stats=group_stats)
py.iplot(fig, filename='Multiple Violins')
# Out:
# The draw time for this plot will be slow for clients without much RAM.
# /usr/local/lib/python2.7/dist-packages/plotly/api/v1/clientresp.py:40: UserWarning:
#
# Estimated Draw Time Slow
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mainakchain/4.embed" height="500px" width="800px"></iframe>

# %%
test1
# Out:
#                            route  delivery
# 6985    Garividi - Visakhapatnam      22.0
# 6986    Garividi - Visakhapatnam      63.0
# 6987    Garividi - Visakhapatnam      22.0
# 6988    Garividi - Visakhapatnam      22.0
# 6989    Garividi - Visakhapatnam      22.0
# 6990    Garividi - Visakhapatnam      22.0
# 6991    Garividi - Visakhapatnam      22.0
# 6992    Garividi - Visakhapatnam      22.0
# 6993    Garividi - Visakhapatnam      60.0
# 6994    Garividi - Visakhapatnam     257.0
# 6995    Garividi - Visakhapatnam      22.0
# 6996    Garividi - Visakhapatnam      22.0
# 6997    Garividi - Visakhapatnam     167.0
# 6998    Garividi - Visakhapatnam      22.0
# 6999    Garividi - Visakhapatnam      22.0
# 7000    Garividi - Visakhapatnam      11.0
# 7001    Garividi - Visakhapatnam       4.0
# 7002    Garividi - Visakhapatnam      22.0
# 7018              Noida - Nagpur     360.0
# 7019           Bamnipal - Jajpur      23.0
# 7020           Bamnipal - Jajpur      23.0
# 7021           Bamnipal - Jajpur      23.0
# 7022           Bamnipal - Jajpur      23.0
# 7023           Bamnipal - Jajpur      23.0
# 7038           Bamnipal - Jajpur      22.0
# 7039           Bamnipal - Jajpur      23.0
# 7040           Bamnipal - Jajpur      23.0
# 7041           Bamnipal - Jajpur      23.0
# 7042           Bamnipal - Jajpur      23.0
# 7043           Bamnipal - Jajpur      23.0
# ...                          ...       ...
# 20815   Bamnipal - Visakhapatnam      14.0
# 20816   Bamnipal - Visakhapatnam      16.0
# 20830         Jamshedpur - PATNA      45.0
# 20831         Jamshedpur - KORBA     130.0
# 20836    Garbham - Visakhapatnam      -6.0
# 20849         Jamshedpur - KORBA     108.0
# 20879       Jamshedpur - KOLKATA      88.0
# 20880       Jamshedpur - KOLKATA      77.0
# 20883  Dhenkanal - Visakhapatnam      14.0
# 20884  Dhenkanal - Visakhapatnam      14.0
# 20887  Dhenkanal - Visakhapatnam      13.0
# 20888  Dhenkanal - Visakhapatnam      31.0
# 20889  Dhenkanal - Visakhapatnam      -2.0
# 20895    Bamaloi - Visakhapatnam      17.0
# 20912    Bamaloi - Visakhapatnam      17.0
# 20931       Jamshedpur - KOLKATA      81.0
# 20935        Jamshedpur - HOWRAH      73.0
# 20937       Jamshedpur - KOLKATA      77.0
# 20944       Jamshedpur - KOLKATA      53.0
# 20954       Jamshedpur - KOLKATA      77.0
# 20970          Bamnipal - Jajpur      23.0
# 20973          Bamnipal - Jajpur      23.0
# 20975  Dhenkanal - Visakhapatnam      13.0
# 20976  Dhenkanal - Visakhapatnam      10.0
# 20980          Bamnipal - Jajpur      23.0
# 20981          Bamnipal - Jajpur      23.0
# 20982          Bamnipal - Jajpur      23.0
# 20984          Bamnipal - Jajpur      23.0
# 21000  Dhenkanal - Visakhapatnam      14.0
# 21086   Garividi - Visakhapatnam      21.0
#
# [5216 rows x 2 columns]

# %%
#violin plot showing the distribution of delays and early transport
import plotly.plotly as py
import plotly.figure_factory as ff
from plotly.graph_objs import graph_objs

import numpy as np
from scipy import stats

data_list = np.random.randn(100)
data_list.tolist()

fig = ff.create_violin(data_list, colors='#604d9e')
py.iplot(fig, filename='')

# %%
data_list = list(test1['delivery'][test1['route'] == 'Garividi - Visakhapatnam'])

fig = ff.create_violin(data_list, colors='#604d9e', height=1000, width=1000)
py.iplot(fig, filename='One Violin')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mainakchain/6.embed" height="1000px" width="1000px"></iframe>

# %%
 ax = sns.violinplot(x="route", y="delivery_hours",data=test, dodge=False)

# %%
plt.show()

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
from plotly.graph_objs import graph_objs

import numpy as np
import pandas as pd
from scipy import stats

np.random.seed(619517)
Nr = 250
y = np.random.randn(Nr)
gr = np.random.choice(list("ABCDE"), Nr)
norm_params = [(0, 1.2), (0.7, 1), (-0.5, 1.4), (0.3, 1), (0.8, 0.9)]

for i, letter in enumerate("ABCDE"):
    y[gr == letter] *= norm_params[i][1] + norm_params[i][0]
df = pd.DataFrame(dict(Score = y, Group = gr))

fig = ff.create_violin(df, data_header='Score', group_header='Group',
                       height=500, width=800)
py.iplot(fig, filename='Multiple Violins')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-729-657115eb5478> in <module>()
#      20 fig = ff.create_violin(df, data_header='Score', group_header='Group',
#      21                        height=500, width=800)
# ---> 22 py.iplot(fig, filename='Multiple Violins')
#
# /usr/local/lib/python2.7/dist-packages/plotly/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     133     if 'auto_open' not in plot_options:
#     134         plot_options['auto_open'] = False
# --> 135     url = plot(figure_or_data, **plot_options)
#     136
#     137     if isinstance(figure_or_data, dict):
#
# /usr/local/lib/python2.7/dist-packages/plotly/plotly/plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     226     data = fig.get('data', [])
#     227     plot_options['layout'] = fig.get('layout', {})
# --> 228     response = v1.clientresp(data, **plot_options)
#     229
#     230     # Check if the url needs a secret key
#
# /usr/local/lib/python2.7/dist-packages/plotly/api/v1/clientresp.pyc in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /usr/local/lib/python2.7/dist-packages/plotly/api/v1/utils.pyc in request(method, url, **kwargs)
#      83         status_code = response.status_code if response else None
#      84         content = response.content if response else 'No content'
# ---> 85         raise exceptions.PlotlyRequestError(message, status_code, content)
#      86     validate_response(response)
#      87     return response
#
# PlotlyRequestError: HTTPSConnectionPool(host='plot.ly', port=443): Max retries exceeded with url: /clientresp (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f7ae0911650>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
